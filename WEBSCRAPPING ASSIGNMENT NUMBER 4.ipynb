# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException
import requests

# %%
driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
rank=[]
name=[]
artist=[]
upload=[]
views=[]

# %%
try:
    rank_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank_tags:
        rank.append(i.text)
except NoSuchElementException:
    rank.append('No Deatails')
    
    
try:
    name_tags= driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name_tags:
        name.append(i.text)
        
except NoSuchElementException:
    name.append('No Details')
    
try:
    artist_tags= driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
    for i in artist_tags:
        artist.append(i.text)
except NoSuchElementException:
    artist.append('No Details')
    
try:
    upload_tags= driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
    for i in upload_tags:
        upload.append(i.text)
        
except NoSuchElementException:
    upload.append('No Details')
try:
    views_tags= driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
    for i in views_tags:
        views.append(i.text)
        
except NoSuchElementException:
    views.append('No Details')

# %%
print(len(rank),len(name),len(artist),len(upload),len(views))
# Out:
# 30 30 30 30 30

# %%
df=pd.DataFrame({'Rank':rank,'Name':name,'Artist':artist,'Upload':upload,'Views In Billions':views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                     "Axel F"[34]
# 14  15.                                      "Sugar"[35]
# ...

# %%
#Question nomber 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
Url = https://www.bcci.tv/.You need to find following details: A) Match title (I.e. 1stODI) B) Series C) Place D) Date E) Time

# %%
driver1=webdriver.Chrome(r"C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\721617797.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1=webdriver.Chrome(r"C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe")

# %%
driver1.get('http://www.bcci.tv/')
driver1.maximize_window()

# %%
international=driver1.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
result=driver1.find_element(By.XPATH,'/html/body/div[2]/div[1]/div/ul/li[2]/a')
result.click()

# %%
match=[]
series=[]
place=[]
date=[]
time=[]
result=[]

# %%
match_tag=driver1.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in match_tag:
    match.append(i.text)

series_tag=driver1.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
for i in series_tag:
    series.append(i.text)

place_tag=driver1.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]/span[3]')
for i in place_tag:
    place.append(i.text)
    
date_tag=driver1.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
for i in date_tag:
    date.append(i.text)
    
time_tag=driver1.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in time_tag:
    time.append(i.text)

# %%
len(match),len(series),len(place),len(date),len(time)
# Out:
# (8, 8, 8, 8, 8)

# %%
df=pd.DataFrame({'Match':match,'Series':series,'Place':place,'Date':date,'Time':time})
df
# Out:
#           Match                         Series          Place         Date  \
# 0     3rd ODI -   AUSTRALIA TOUR OF INDIA 2023        Chennai  22 MAR 2023
# 1     2nd ODI -   AUSTRALIA TOUR OF INDIA 2023  Visakhapatnam  19 MAR 2023
# 2     1st ODI -   AUSTRALIA TOUR OF INDIA 2023         Mumbai  17 MAR 2023
# 3    4th Test -   AUSTRALIA TOUR OF INDIA 2023      Ahmedabad   9 MAR 2023
# 4    3rd Test -   AUSTRALIA TOUR OF INDIA 2023         Indore   1 MAR 2023
# 5  Semi Final -  ICC WOMENS T20 WORLD CUP 2023      Cape Town  23 FEB 2023
# 6    4th T20I -  ICC WOMENS T20 WORLD CUP 2023       Gqeberha  20 FEB 2023
# 7    3rd T20I -  ICC WOMENS T20 WORLD CUP 2023       Gqeberha  18 FEB 2023
#
#           Time
# 0  1:30 PM IST
# 1  1:30 PM IST
# 2  1:30 PM IST
# 3  9:30 AM IST
# 4  9:30 AM IST
# 5  6:30 PM IST
# 6  6:30 PM IST
# 7  6:30 PM IST

# %%
driver.get('https://www.statisticstimes.com/')

# %%
search=driver.find_element(By.XPATH,'//div[@class="navbar"]')
search.click()

# %%
#clicking on economy button
economy=driver.find_element(By.XPATH,"//div[@class='dropdown'][2]/div/a[3]")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))
time.sleep(2)


#clicking on gdp of indian states
indian_states=driver.find_element(By.XPATH,"//ul[@style='list-style-type:none;margin-left:20px;']//li[1]/a")

try:
    indian_states.click()
except ElementNotInteractableException:
    driver.get(indian_states.get_attribute('href')) 
time.sleep(2)


#scraping rank
rank=[]
try:
    ranks=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:                 #handling no such element exception
    rank.append('No details available')
time.sleep(2)


#scraping States
State=[]
try:
    states=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in states:
        State.append(i.text)
except NoSuchElementException:                 #handling no such element exception
    State.append('No details available')
time.sleep(2)


#scraping GSDP(19-20)
GSDP_20=[]
try:
    info=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in info:
        GSDP_20.append(i.text)
except NoSuchElementException:           #handling no such element exception
    GSDP_20.append('No details available')
time.sleep(2)    
    
#scraping GSDP(18-19)
GSDP_19=[]
try:
    info=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in info:
        GSDP_19.append(i.text)
except NoSuchElementException:        #handling no such element exception
    GSDP_19.append('No details available')
time.sleep(2)

#scraping share (18-19)
share=[]
try:
    info=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in info:
        share.append(i.text)
except NoSuchElementException:          #handling no such element exception
    share.append('No details available')
time.sleep(2)

#scraping GDP(billion$)
GDP_billion=[]
try:
    info=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in info:
        GDP_billion.append(i.text)
except NoSuchElementException:            #handling no such element exception
    GDP_billion.append('No details available')
time.sleep(2)

# %%
df=pd.DataFrame({'Rank':rank,
                'State':State,
                'GSDP(19-20)':GSDP_20,
                'GSDP(18-19)':GSDP_19,
                'Share(18-19)':share,
                'GDP(Billion_$)':GDP_billion})
df
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# ...

# %%
#Question number 4 Scrape the details of trending repositories on Github.com.
Url = https://github.com/
You have to find the following details:
A) Repository title
B) Repository description
C) Contributors count
D) Language used

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver3=webdriver.Chrome(r'C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe')
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\476752700.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome(r'C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe')

# %%
driver3.get('https://github.com/')

# %%
source=driver3.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
source.click()

# %%
trending=driver3.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
title_url=[]
url=driver3.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]/a')
for i in url:
    title_url.append(i.get_attribute('href'))

# %%
len(title_url)
# Out:
# 25

# %%
import time
from time import sleep

# %%
titl=[]

for i in title_url:
    driver3.get(i)
    time.sleep(3)
    try:
        ti_tag=driver3.find_element(By.XPATH,'//strong[@class="mr-2 flex-self-stretch"]')
        titl.append(ti_tag.text)
    except NoSuchElementException:
        titl.append("-")

# %%
description=[]

for i in title_url:
    driver3.get(i)
    time.sleep(3)
    try:
        d_tag=driver3.find_element(By.XPATH,'//p[@class="f4 my-3"]')
        description.append(d_tag.text)
    except NoSuchElementException:
        description.append("-")

# %%
len(title_url),len(titl),len(description)
# Out:
# (25, 25, 25)

# %%
df=pd.DataFrame({'Repository title':titl,'Repository description':description})
df
# Out:
#             Repository title  \
# 0                     LaWGPT
# 1              voice-changer
# 2                    Flowise
# 3            next-enterprise
# 4         awesome-selfhosted
# 5              the-algorithm
# 6                     yt-fts
# 7   Prompt-Engineering-Guide
# 8                      helix
# 9                gpt-code-ui
# 10                      FUE5
# 11     MaaAssistantArknights
# 12                 egos-2000
# 13                   DragGAN
# 14                   klipper
# 15                     quivr
# 16                EasySpider
# 17                  snake-ai
# 18              StableStudio
# 19   nlw-12-spacetime-ignite
# 20                 SpeechGPT
# 21                     AGiXT
# 22                      Qbot
# 23   awesome-chatgpt-prompts
# 24         awesome-langchain
#
#                                Repository description
# 0   🎉 Repo for LaWGPT, Chinese-Llama tuned with Ch...
# 1              リアルタイムボイスチェンジャー Realtime Voice Changer
# ...

# %%
driver.close()

# %%
#Question number 5 Scrape the details of top 100 songs on billiboard.com. 
Url = https:/www.billboard.com/
You have to find the following details:
A) Song name
B) Artist name
C) Last week rank
D) Peak rank
E) Weeks on board
Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\3775428138.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.billboard.com/"
driver.get(url)

# %%
chart=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
chart.click()

# %%
view=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
view.click()

# %%
song=[]
artist=[]
lw_rank=[]
p_rank=[]
weeks=[]

# %%
song_tag=driver.find_element(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet"]')
song.append(song_tag.text)
s_tag=driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
for i in s_tag:
    song.append(i.text)

ar_tag=driver.find_element(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
artist.append(ar_tag.text)
art_tag=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in art_tag:
    artist.append(i.text)

# %%
len(song),len(artist)
# Out:
# (100, 100)

# %%
lw_rank=[]
lw_tag=driver.find_elements(By.XPATH,'//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[4]/span')
for i in lw_tag:
    lw_rank.append(i.text)

p_rank=[]
p_tag=driver.find_elements(By.XPATH,'//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[5]/span')
for i in p_tag:
    p_rank.append(i.text)

weeks=[]
week=driver.find_elements(By.XPATH,'//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]/div/ul/li[4]/ul/li[6]/span')
for i in week:
    weeks.append(i.text)

# %%
len(lw_rank),len(p_rank),len(weeks)
# Out:
# (100, 100, 100)

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Song name':song,'Artist name':artist,'Last week rank':lw_rank,'Peak rank':p_rank,'Weeks on board':weeks})
df
# Out:
#                  Song name                                   Artist name  \
# 0               Last Night                                 Morgan Wallen
# 1                Kill Bill                                           SZA
# 2                  Flowers                                   Miley Cyrus
# 3          Ella Baila Sola                   Eslabon Armado X Peso Pluma
# 4                Calm Down                           Rema & Selena Gomez
# ..                     ...                                           ...
# 95                Wreckage                                    Nate Smith
# 96                Curtains                                    Ed Sheeran
# 97  What It Is (Block Boy)                 Doechii Featuring Kodak Black
# 98                 Peaches                                    Jack Black
# 99         Private Landing  Don Toliver Featuring Justin Bieber & Future
#
#    Last week rank Peak rank Weeks on board
# 0               1         1             15
# ...

# %%
driver.close()

# %%
#Question number 6 Scrape the details of Highest sellingnovels.
Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare
You have to find the following details:
A) Book name
B) Author name
C) Volumes sold
D) Publisher
E) Genre

# %%
driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\3775428138.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
book_name=[]
author_name=[]
book_sold=[]
publisher=[]
genre=[]

# %%
book_tag=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in book_tag:
    book_name.append(i.text)

author_tag=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author_tag:
    author_name.append(i.text)
    
sold_tag=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in sold_tag:
    book_sold.append(i.text)
    
pub_tag=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in pub_tag:
    publisher.append(i.text)
    
genre_tag=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in genre_tag:
    genre.append(i.text)

# %%
import pandas as pd

# %%
len(book_name),len(author_name),len(book_sold),len(publisher),len(genre)
# Out:
# (100, 100, 100, 100, 100)

# %%
df=pd.DataFrame({'Title':book_name,'Author':author_name,'Volume sold':book_sold,'Publisher':publisher,'Genre':genre})
df
# Out:
#                                                 Title            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %%
driver.close()

# %%
#Question number 7. Scrape the details most watched tv series of all time from imdb.com. 
Url = https://www.imdb.com/list/ls095964455/
You have to find the following details:
A) Name
B) Year span
C) Genre
D) Run time
E) Ratings
F) Votes

# %%
driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\3775428138.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('http://www.imdb.com/list/ls095964455/')

# %%
name=[]
year=[]
genre=[]
runtime=[]
rating=[]
voting=[]

# %%
name_tag=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/h3/a')
for i in name_tag:
    name.append(i.text)

year_tag=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/h3/span[2]')
for i in year_tag:
    year.append(i.text)
    
genre_tag=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/p/span[5]')
for i in genre_tag:
    genre.append(i.text)
    
run_tag=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/p/span[3]')
for i in run_tag:
    runtime.append(i.text)
    
rate_tag=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/div/div[1]/span[2]')
for i in rate_tag:
    rating.append(i.text)
    
vote=driver.find_elements(By.XPATH,'//div[@class="lister-list"]/div/div[2]/p[4]/span[2]')
for i in vote:
    voting.append(i.text)

# %%
len(name),len(year),len(genre),len(runtime),len(rating),len(voting)
# Out:
# (100, 100, 100, 100, 100, 100)

# %%
df=pd.DataFrame({'Name':name,'Year span':year,'Genre':genre,'Runtime':runtime,'Rating':rating,'Voting':voting})
df
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2022)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House     (2018– )    Drama, Horror, Mystery
#
#     Runtime Rating     Voting
# 0    57 min    9.2  2,161,658
# ...

# %%
driver.close()

# %%
#Question number 8. Details of Datasetsfrom UCI machine learning repositories. 
Url = https://archive.ics.uci.edu/
You have to find the following details:
A) Dataset name
B) Data type
C) Task
D) Attribute type
E) No of instances
F) No of attribute
G) Year
Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\3775428138.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"D:\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
viewall=driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]')
viewall.click()

# %%
dataname=[]
datatype=[]
task=[]
attribute_type=[]
instance=[]
attribute=[]
year=[]

# %%
data_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[1]')
for i in data_tag[1:623]:
    dataname.append(i.text)
    
datatype_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[2]')
for i in datatype_tag[1:623]:
    datatype.append(i.text)
    
task_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[3]')
for i in task_tag[1:623]:
    task.append(i.text)
    
type_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[4]')
for i in type_tag[1:623]:
    attribute_type.append(i.text)
    
inst_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[5]')
for i in inst_tag[1:623]:
    instance.append(i.text)
    
att_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[6]')
for i in att_tag[1:623]:
    attribute.append(i.text)
    
y_tag=driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[7]')
for i in y_tag[1:623]:
    year.append(i.text)

# %%
len(dataname),len(datatype),len(task),len(attribute_type),len(instance),len(attribute),len(year)
# Out:
# (622, 622, 622, 622, 622, 622, 622)

# %%
df=pd.DataFrame({'Dataname':dataname,'Datatype':datatype,'Task':task,'Attribute type':attribute_type,'NO of instances':instance,'NO of attribute':attribute,'Year':year})
df
# Out:
#                                               Dataname  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617    Influenza outbreak event prediction via Twit...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621    Image Recognition Task Execution Times in Mo...
#
#                        Datatype                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
#Question number 9. Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants
You have to find the following details: 
A) Name
B) Designation
C)Company 
D)Skills they hire for 
E) Location

# %%
driver8=webdriver.Chrome(r"C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe")
# Out:
# C:\Users\Rhsha\AppData\Local\Temp\ipykernel_6916\505358334.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver8=webdriver.Chrome(r"C:\Users\User\Desktop\veeresh\Internship(test)/chromedriver.exe")

# %%
driver8.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
skill=driver8.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
skill.send_keys('Data science')

# %%
search=driver8.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
search.click()

# %%
name=[]
designation=[]
company=[]
skill=[]
location=[]

# %%
name_tag=driver8.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
for i in name_tag:
    name.append(i.text)
    
des_tag=driver8.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
for i in des_tag:
    designation.append(i.text)

com_tag=driver8.find_elements(By.XPATH,'//a[@class="ellipsis"][2]')
for i in com_tag:
    company.append(i.text)

skill_tag=driver8.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
for i in skill_tag:
    skill.append(i.text)

# %%
url=[]
name_url=driver8.find_elements(By.XPATH,'//a[@class="ellipsis"][1]')
for i in name_url:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.naukri.com/recruiters/aakashharit-1986742?xid=168482553654635300&xp=1',
#  'https://www.naukri.com/recruiters/shravankumargaddam-353487?xid=168482553654635300&xp=2',
#  'https://www.naukri.com/recruiters/marsiantech?xid=168482553654635300&xp=3',
#  'https://www.naukri.com/recruiters/anikagrawal-3647208?xid=168482553654635300&xp=4',
#  'https://www.naukri.com/recruiters/LXP-DATASCIENCE?xid=168482553654635300&xp=5',
#  'https://www.naukri.com/recruiters/abhishekyadav-3450244?xid=168482553654635300&xp=6',
#  'https://www.naukri.com/recruiters/menakav-3213816?xid=168482553654635300&xp=7',
#  'https://www.naukri.com/recruiters/techvantage?xid=168482553654635300&xp=8',
#  'https://www.naukri.com/recruiters/asiflucknowi-4331110?xid=168482553654635300&xp=9',
#  'https://www.naukri.com/recruiters/instafinancials-humanresource?xid=168482553654635300&xp=10',
#  'https://www.naukri.com/recruiters/kalpana-2078894?xid=168482553654635300&xp=11',
# ...

# %%
location=[]
for i in url:
    driver8.get(i)
    try:
        loc_tag=driver8.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[1]/div[2]/div[5]/a')
        location.append(loc_tag.text)
    except NoSuchElementException:
        location.append("-")

# %%
len(name),len(designation),len(company),len(skill),len(location)
# Out:
# (50, 50, 50, 50, 50)

# %%
df=pd.DataFrame({'Name':name,'Designation':designation,'Company':company,'Skills they hire for':skill,'Location':location})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()
