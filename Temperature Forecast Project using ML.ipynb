# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df1=df.drop("station",axis=1)
at=df1.drop("Date",axis=1)

# %%
at.isnull().sum()
# Out:
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
at.dtypes
# Out:
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
To remove the null values, replacing the null values with mean of the coumn as the data type is float

# %%
at['Present_Tmax']=at['Present_Tmax'].replace('',np.nan)

# %%
at['Present_Tmax']=at['Present_Tmax'].fillna(np.mean(at["Present_Tmax"]))

# %%
at['Present_Tmin']=at['Present_Tmin'].replace('',np.nan)

# %%
at['Present_Tmin']=at['Present_Tmin'].fillna(np.mean(at["Present_Tmin"]))

# %%
at['LDAPS_RHmin']=at['LDAPS_RHmin'].replace('',np.nan)

# %%
at['LDAPS_RHmin']=at['LDAPS_RHmin'].fillna(np.mean(at["LDAPS_RHmin"]))

# %%
at['LDAPS_RHmax']=at['LDAPS_RHmax'].replace('',np.nan)

# %%
at['LDAPS_RHmax']=at['LDAPS_RHmax'].fillna(np.mean(at["LDAPS_RHmax"]))

# %%
at['LDAPS_Tmax_lapse']=at['LDAPS_Tmax_lapse'].replace('',np.nan)

# %%
at['LDAPS_Tmax_lapse']=at['LDAPS_Tmax_lapse'].fillna(np.mean(at["LDAPS_Tmax_lapse"]))

# %%
at['LDAPS_Tmin_lapse']=at['LDAPS_Tmin_lapse'].replace('',np.nan)

# %%
at['LDAPS_Tmin_lapse']=at['LDAPS_Tmin_lapse'].fillna(np.mean(at["LDAPS_Tmin_lapse"]))

# %%
at['LDAPS_WS']=at['LDAPS_WS'].replace('',np.nan)

# %%
at['LDAPS_WS']=at['LDAPS_WS'].fillna(np.mean(at["LDAPS_WS"]))

# %%
at['LDAPS_LH']=at['LDAPS_LH'].replace('',np.nan)

# %%
at['LDAPS_LH']=at['LDAPS_LH'].fillna(np.mean(at["LDAPS_LH"]))

# %%
at['LDAPS_CC1']=at['LDAPS_CC1'].replace('',np.nan)

# %%
at['LDAPS_CC1']=at['LDAPS_CC1'].fillna(np.mean(at["LDAPS_CC1"]))

# %%
at['LDAPS_CC2']=at['LDAPS_CC2'].replace('',np.nan)

# %%
at['LDAPS_CC2']=at['LDAPS_CC2'].fillna(np.mean(at["LDAPS_CC2"]))

# %%
at['LDAPS_CC3']=at['LDAPS_CC3'].replace('',np.nan)

# %%
at['LDAPS_CC3']=at['LDAPS_CC3'].fillna(np.mean(at["LDAPS_CC3"]))

# %%
at['LDAPS_CC4']=at['LDAPS_CC4'].replace('',np.nan)

# %%
at['LDAPS_CC4']=at['LDAPS_CC4'].fillna(np.mean(at["LDAPS_CC4"]))

# %%
at['LDAPS_PPT1']=at['LDAPS_PPT1'].replace('',np.nan)

# %%
at['LDAPS_PPT1']=at['LDAPS_PPT1'].fillna(np.mean(at["LDAPS_PPT1"]))

# %%
at['LDAPS_PPT2']=at['LDAPS_PPT2'].replace('',np.nan)

# %%
at['LDAPS_PPT2']=at['LDAPS_PPT2'].fillna(np.mean(at["LDAPS_PPT2"]))

# %%
at['LDAPS_PPT3']=at['LDAPS_PPT3'].replace('',np.nan)

# %%
at['LDAPS_PPT3']=at['LDAPS_PPT3'].fillna(np.mean(at["LDAPS_PPT3"]))

# %%
at['LDAPS_PPT4']=at['LDAPS_PPT4'].replace('',np.nan)

# %%
at['LDAPS_PPT4']=at['LDAPS_PPT4'].fillna(np.mean(at["LDAPS_PPT4"]))

# %%
at['Next_Tmax']=at['Next_Tmax'].replace('',np.nan)

# %%
at['Next_Tmax']=at['Next_Tmax'].fillna(np.mean(at["Next_Tmax"]))

# %%
at['Next_Tmin']=at['Next_Tmin'].replace('',np.nan)

# %%
at['Next_Tmin']=at['Next_Tmin'].fillna(np.mean(at["Next_Tmin"]))

# %%
at.isnull().sum()
# Out:
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
tm=at.drop("Next_Tmin",axis=1)
tm
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0             28.7          21.4    58.255688    91.116364         28.074101
# 1             31.9          21.6    52.263397    90.604721         29.850689
# 2             31.6          23.3    48.690479    83.973587         30.091292
# 3             32.0          23.4    58.239788    96.483688         29.704629
# 4             31.4          21.9    56.174095    90.155128         29.113934
# ...            ...           ...          ...          ...               ...
# 7747          23.3          17.1    26.741310    78.869858         26.352081
# 7748          23.3          17.7    24.040634    77.294975         27.010193
# 7749          23.2          17.4    22.933014    77.243744         27.939516
# 7750          20.0          11.3    19.794666    58.936283         17.624954
# 7751          37.6          29.9    98.524734   100.000153         38.542255
#
#       LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            23.006936   6.818887   69.451805   0.233947   0.203896  ...
# 1            24.035009   5.691890   51.937448   0.225508   0.251771  ...
# 2            24.565633   6.138224   20.573050   0.209344   0.257469  ...
# 3            23.326177   5.650050   65.727144   0.216372   0.226002  ...
# 4            23.486480   5.735004  107.965535   0.151407   0.249995  ...
# ...                ...        ...         ...        ...        ...  ...
# 7747         18.775678   6.148918   72.058294   0.030034   0.081035  ...
# 7748         18.733519   6.542819   47.241457   0.035874   0.074962  ...
# 7749         18.522965   7.289264    9.090034   0.048954   0.059869  ...
# 7750         14.272646   2.882580  -13.603212   0.000000   0.000000  ...
# 7751         29.619342  21.857621  213.414006   0.967277   0.968353  ...
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon  \
# 0       0.000000    0.000000    0.000000    0.000000  37.6046  126.991
# 1       0.000000    0.000000    0.000000    0.000000  37.6046  127.032
# 2       0.000000    0.000000    0.000000    0.000000  37.5776  127.058
# 3       0.000000    0.000000    0.000000    0.000000  37.6450  127.022
# 4       0.000000    0.000000    0.000000    0.000000  37.5507  127.135
# ...          ...         ...         ...         ...      ...      ...
# 7747    0.000000    0.000000    0.000000    0.000000  37.5372  126.891
# 7748    0.000000    0.000000    0.000000    0.000000  37.5237  126.909
# 7749    0.000000    0.000000    0.000000    0.000000  37.5237  126.970
# 7750    0.000000    0.000000    0.000000    0.000000  37.4562  126.826
# 7751   23.701544   21.621661   15.841235   16.655469  37.6450  127.135
#
#            DEM     Slope  Solar radiation  Next_Tmax
# 0     212.3350  2.785000      5992.895996       29.1
# 1      44.7624  0.514100      5869.312500       30.5
# 2      33.3068  0.266100      5863.555664       31.1
# 3      45.7160  2.534800      5856.964844       31.7
# 4      35.0380  0.505500      5859.552246       31.2
# ...        ...       ...              ...        ...
# 7747   15.5876  0.155400      4443.313965       28.3
# 7748   17.2956  0.222300      4438.373535       28.6
# 7749   19.5844  0.271300      4451.345215       27.8
# 7750   12.3700  0.098475      4329.520508       17.4
# 7751  212.3350  5.178230      5992.895996       38.9
#
# [7752 rows x 22 columns]

# %%
tm.corr()
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.618760    -0.204571    -0.301787
# Present_Tmin          0.618760      1.000000     0.123143    -0.015140
# LDAPS_RHmin          -0.204571      0.123143     1.000000     0.579141
# LDAPS_RHmax          -0.301787     -0.015140     0.579141     1.000000
# LDAPS_Tmax_lapse      0.570129      0.464151    -0.564580    -0.373404
# LDAPS_Tmin_lapse      0.623496      0.762993     0.089476    -0.114143
# LDAPS_WS             -0.121820     -0.034675     0.294361     0.135333
# LDAPS_LH              0.135463     -0.009258    -0.070858     0.238579
# LDAPS_CC1            -0.311805      0.084447     0.613818     0.436652
# LDAPS_CC2            -0.213791      0.090263     0.745443     0.391330
# LDAPS_CC3            -0.144018     -0.002772     0.689679     0.226957
# LDAPS_CC4            -0.140729     -0.044335     0.514075     0.130619
# LDAPS_PPT1           -0.109006      0.112845     0.262665     0.268449
# LDAPS_PPT2           -0.099449      0.068176     0.390967     0.229050
# LDAPS_PPT3           -0.120367     -0.046126     0.240642     0.134607
# LDAPS_PPT4           -0.099607     -0.062965     0.168595     0.117853
# lat                  -0.052615     -0.078475     0.087099     0.195798
# lon                   0.009020     -0.043461    -0.076237     0.025667
# DEM                  -0.187121     -0.250275     0.102115     0.177168
# Slope                -0.105809     -0.146339     0.123744     0.219599
# Solar radiation      -0.025439      0.053578     0.244080     0.149261
# Next_Tmax             0.610348      0.471806    -0.437898    -0.283738
#
#                   LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# Present_Tmax              0.570129          0.623496 -0.121820  0.135463
# Present_Tmin              0.464151          0.762993 -0.034675 -0.009258
# LDAPS_RHmin              -0.564580          0.089476  0.294361 -0.070858
# LDAPS_RHmax              -0.373404         -0.114143  0.135333  0.238579
# LDAPS_Tmax_lapse          1.000000          0.654021 -0.311996  0.048010
# LDAPS_Tmin_lapse          0.654021          1.000000 -0.130035 -0.134761
# LDAPS_WS                 -0.311996         -0.130035  1.000000  0.006711
# LDAPS_LH                  0.048010         -0.134761  0.006711  1.000000
# LDAPS_CC1                -0.438439          0.010901  0.289445 -0.147296
# LDAPS_CC2                -0.523619          0.047727  0.261090 -0.264280
# LDAPS_CC3                -0.541327         -0.044018  0.242991 -0.245583
# LDAPS_CC4                -0.429539         -0.080335  0.220533 -0.172766
# LDAPS_PPT1               -0.111065          0.038056  0.152587 -0.012542
# LDAPS_PPT2               -0.242122          0.000870  0.191886 -0.077545
# LDAPS_PPT3               -0.188115         -0.088575  0.161684  0.016102
# LDAPS_PPT4               -0.160273         -0.094655  0.144085  0.019979
# lat                      -0.042093         -0.096257  0.036657  0.133221
# lon                       0.090666         -0.026701 -0.059466  0.025822
# DEM                      -0.178895         -0.195455  0.191053  0.055133
# Slope                    -0.162332         -0.185849  0.171629  0.086781
# Solar radiation           0.047971          0.159975  0.121759 -0.047384
# Next_Tmax                 0.827189          0.586983 -0.342729  0.157616
#
#                   LDAPS_CC1  LDAPS_CC2  ...  LDAPS_PPT1  LDAPS_PPT2  \
# Present_Tmax      -0.311805  -0.213791  ...   -0.109006   -0.099449
# Present_Tmin       0.084447   0.090263  ...    0.112845    0.068176
# LDAPS_RHmin        0.613818   0.745443  ...    0.262665    0.390967
# LDAPS_RHmax        0.436652   0.391330  ...    0.268449    0.229050
# LDAPS_Tmax_lapse  -0.438439  -0.523619  ...   -0.111065   -0.242122
# LDAPS_Tmin_lapse   0.010901   0.047727  ...    0.038056    0.000870
# LDAPS_WS           0.289445   0.261090  ...    0.152587    0.191886
# LDAPS_LH          -0.147296  -0.264280  ...   -0.012542   -0.077545
# LDAPS_CC1          1.000000   0.779683  ...    0.446328    0.389453
# LDAPS_CC2          0.779683   1.000000  ...    0.305975    0.478472
# LDAPS_CC3          0.517493   0.725813  ...    0.159280    0.337569
# LDAPS_CC4          0.361046   0.527708  ...    0.120483    0.288195
# LDAPS_PPT1         0.446328   0.305975  ...    1.000000    0.383831
# LDAPS_PPT2         0.389453   0.478472  ...    0.383831    1.000000
# LDAPS_PPT3         0.168742   0.240134  ...    0.033004    0.221172
# LDAPS_PPT4         0.091722   0.159548  ...    0.024626    0.139555
# lat               -0.008131  -0.001497  ...    0.000565    0.019564
# lon               -0.006843  -0.003581  ...   -0.001225    0.018600
# DEM               -0.014090  -0.012823  ...    0.011290    0.008357
# Slope             -0.020752  -0.018073  ...    0.016310    0.010214
# Solar radiation    0.218309   0.170403  ...    0.088015    0.110182
# Next_Tmax         -0.452541  -0.490756  ...   -0.118817   -0.178383
#
#                   LDAPS_PPT3  LDAPS_PPT4       lat       lon       DEM  \
# Present_Tmax       -0.120367   -0.099607 -0.052615  0.009020 -0.187121
# Present_Tmin       -0.046126   -0.062965 -0.078475 -0.043461 -0.250275
# LDAPS_RHmin         0.240642    0.168595  0.087099 -0.076237  0.102115
# LDAPS_RHmax         0.134607    0.117853  0.195798  0.025667  0.177168
# LDAPS_Tmax_lapse   -0.188115   -0.160273 -0.042093  0.090666 -0.178895
# LDAPS_Tmin_lapse   -0.088575   -0.094655 -0.096257 -0.026701 -0.195455
# LDAPS_WS            0.161684    0.144085  0.036657 -0.059466  0.191053
# LDAPS_LH            0.016102    0.019979  0.133221  0.025822  0.055133
# LDAPS_CC1           0.168742    0.091722 -0.008131 -0.006843 -0.014090
# LDAPS_CC2           0.240134    0.159548 -0.001497 -0.003581 -0.012823
# LDAPS_CC3           0.339800    0.302357  0.004108  0.016041  0.000697
# LDAPS_CC4           0.267494    0.376049 -0.009107 -0.002477 -0.007334
# LDAPS_PPT1          0.033004    0.024626  0.000565 -0.001225  0.011290
# LDAPS_PPT2          0.221172    0.139555  0.019564  0.018600  0.008357
# LDAPS_PPT3          1.000000    0.309076  0.035110  0.021662  0.017186
# LDAPS_PPT4          0.309076    1.000000  0.013210  0.044746 -0.003622
# lat                 0.035110    0.013210  1.000000  0.289029  0.033165
# lon                 0.021662    0.044746  0.289029  1.000000  0.007587
# DEM                 0.017186   -0.003622  0.033165  0.007587  1.000000
# Slope               0.025333    0.000117  0.074763  0.038070  0.783576
# Solar radiation    -0.054071    0.034958  0.038513  0.002182  0.056224
# Next_Tmax          -0.194143   -0.178718 -0.053510  0.003052 -0.172538
#
#                      Slope  Solar radiation  Next_Tmax
# Present_Tmax     -0.105809        -0.025439   0.610348
# Present_Tmin     -0.146339         0.053578   0.471806
# LDAPS_RHmin       0.123744         0.244080  -0.437898
# LDAPS_RHmax       0.219599         0.149261  -0.283738
# LDAPS_Tmax_lapse -0.162332         0.047971   0.827189
# LDAPS_Tmin_lapse -0.185849         0.159975   0.586983
# LDAPS_WS          0.171629         0.121759  -0.342729
# LDAPS_LH          0.086781        -0.047384   0.157616
# LDAPS_CC1        -0.020752         0.218309  -0.452541
# LDAPS_CC2        -0.018073         0.170403  -0.490756
# LDAPS_CC3        -0.003338         0.119292  -0.514680
# LDAPS_CC4        -0.014459         0.119983  -0.446319
# LDAPS_PPT1        0.016310         0.088015  -0.118817
# LDAPS_PPT2        0.010214         0.110182  -0.178383
# LDAPS_PPT3        0.025333        -0.054071  -0.194143
# LDAPS_PPT4        0.000117         0.034958  -0.178718
# lat               0.074763         0.038513  -0.053510
# lon               0.038070         0.002182   0.003052
# DEM               0.783576         0.056224  -0.172538
# Slope             1.000000         0.028199  -0.102725
# Solar radiation   0.028199         1.000000   0.008795
# Next_Tmax        -0.102725         0.008795   1.000000
#
# [22 rows x 22 columns]

# %%
tm.corr()['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.827189
# Present_Tmax        0.610348
# LDAPS_Tmin_lapse    0.586983
# Present_Tmin        0.471806
# LDAPS_LH            0.157616
# Solar radiation     0.008795
# lon                 0.003052
# lat                -0.053510
# Slope              -0.102725
# LDAPS_PPT1         -0.118817
# DEM                -0.172538
# LDAPS_PPT2         -0.178383
# LDAPS_PPT4         -0.178718
# LDAPS_PPT3         -0.194143
# LDAPS_RHmax        -0.283738
# LDAPS_WS           -0.342729
# LDAPS_RHmin        -0.437898
# LDAPS_CC4          -0.446319
# LDAPS_CC1          -0.452541
# LDAPS_CC2          -0.490756
# LDAPS_CC3          -0.514680
# Name: Next_Tmax, dtype: float64

# %%
We see that the major factors contributing to next days maximum temperature are LDAPS_Tmax_lapse Present_Tmax, LDAPS_Tmin_lapse ,Present_Tmin ,LDAPS_LH. On the other hand LDAPS_RHmax,LDAPS_WS ,LDAPS_RHmin ,LDAPS_CC4,LDAPS_CC1,LDAPS_CC2, LDAPS_CC3 are negatively correlated to Next_Tmax

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(tm.corr(),annot=True)
# Out:
# <Axes: >

# %%
tm.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7752.000000   7752.000000  7752.000000  7752.000000       7752.000000
# mean      29.768211     23.225059    56.759372    88.374804         29.613447
# std        2.956557      2.403036    14.596973     7.157124          2.932898
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.046162    84.316923         27.693091
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.900000    67.038254    93.704500         31.683819
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean          23.512589     7.097875    62.505019     0.368774     0.356080
# std            2.333973     2.173245    33.567001     0.261185     0.256810
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.114651     5.686487    37.532764     0.148321     0.142328
# 50%           23.735942     6.563068    57.310630     0.320110     0.315667
# 75%           25.134000     8.007471    83.904586     0.571696     0.554963
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean   ...     0.591995     0.485003     0.278200     0.269407    37.544722
# std    ...     1.936331     1.754258     1.156174     1.200364     0.050352
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.067593     0.024276     0.009697     0.000693    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax
# count  7752.000000  7752.000000  7752.000000      7752.000000  7752.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.122557
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
# [8 rows x 22 columns]

# %%
tm.plot(kind='density',subplots=True,layout=(6,6),sharex=False,legend=False, fontsize=1,figsize=(18,12))
plt.show()

# %%
Now to seperate dependent and independent variables, x and y,

# %%
x=tm.drop("Next_Tmax",axis=1)
y=tm["Next_Tmax"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          6.825464
# LDAPS_PPT3          6.457129
# LDAPS_PPT2          5.775355
# LDAPS_PPT1          5.393821
# DEM                 1.723257
# LDAPS_WS            1.579236
# Slope               1.563020
# LDAPS_LH            0.673757
# LDAPS_CC4           0.666482
# LDAPS_CC3           0.640735
# LDAPS_CC2           0.472350
# LDAPS_CC1           0.459458
# LDAPS_RHmin         0.300220
# lat                 0.087062
# LDAPS_Tmax_lapse   -0.227880
# Present_Tmax       -0.264137
# lon                -0.285213
# Present_Tmin       -0.367538
# Solar radiation    -0.511210
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_RHmax        -0.855015
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4           lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  4.163336e-17
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  4.163336e-17
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  1.387779e-17
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  8.326673e-17
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.000000e+00
# ...         ...         ...         ...         ...         ...           ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -8.326673e-17
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  8.326673e-17
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
x.skew().sort_values(ascending=False)
# Out:
# LDAPS_PPT4          1.963848
# LDAPS_PPT3          1.747820
# LDAPS_PPT2          1.577808
# LDAPS_PPT1          1.404189
# Slope               0.233968
# LDAPS_CC4           0.126895
# LDAPS_CC3           0.087933
# LDAPS_LH            0.057403
# LDAPS_CC1           0.046757
# LDAPS_CC2           0.045326
# DEM                 0.039456
# LDAPS_WS            0.002408
# lat                 0.000000
# LDAPS_Tmax_lapse   -0.009351
# Present_Tmin       -0.012048
# LDAPS_RHmin        -0.017469
# LDAPS_Tmin_lapse   -0.017827
# Present_Tmax       -0.035006
# LDAPS_RHmax        -0.115143
# Solar radiation    -0.176636
# lon                -0.198429
# dtype: float64

# %%
sk=x.skew()

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.408897     -0.797707     0.172680     0.272915         -0.556645
# 1         0.705123     -0.720130    -0.241770     0.185831          0.043756
# 2         0.595692     -0.027674    -0.501459    -0.773454          0.127214
# 3         0.741829      0.014910     0.171612     1.316777         -0.006660
# 4         0.523313     -0.602237     0.031496     0.110968         -0.208627
# ...            ...           ...          ...          ...               ...
# 7747     -2.023162     -2.270927    -2.395892    -1.326845         -1.111724
# 7748     -2.023162     -2.087438    -2.681557    -1.470235         -0.902733
# 7749     -2.049920     -2.180066    -2.803707    -1.474702         -0.600985
# 7750     -2.846187     -3.688005    -3.168120    -2.459357         -3.504186
# 7751      2.981037      3.233078     2.489550     2.143982          3.376037
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0            -0.312411  0.093387  0.310382  -0.412176  -0.506509  ...
# 1             0.144368 -0.625565 -0.211695  -0.451258  -0.283702  ...
# 2             0.394571 -0.314874 -1.375126  -0.527382  -0.258127  ...
# 3            -0.174463 -0.656732  0.204179  -0.494077  -0.401828  ...
# 4            -0.103881 -0.593836  1.300503  -0.814752  -0.291713  ...
# ...                ...       ...       ...        ...        ...  ...
# 7747         -1.831134 -0.307886  0.383363  -1.502656  -1.152361  ...
# 7748         -1.843546 -0.063701 -0.363041  -1.466503  -1.187449  ...
# 7749         -1.904782  0.337939 -1.973052  -1.386744  -1.276108  ...
# 7750         -2.891504 -4.119648 -7.414001  -1.694130  -1.649551  ...
# 7751          3.309654  3.033873  3.452681   1.866462   1.920855  ...
#
#       LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4           lat  \
# 0     -0.584801   -0.570471   -0.532418   -0.505596   -0.458389  4.163336e-17
# 1     -0.603593   -0.570471   -0.532418   -0.505596   -0.458389  4.163336e-17
# 2     -0.520112   -0.570471   -0.532418   -0.505596   -0.458389  1.387779e-17
# 3     -0.565449   -0.570471   -0.532418   -0.505596   -0.458389  8.326673e-17
# 4     -0.365736   -0.570471   -0.532418   -0.505596   -0.458389  0.000000e+00
# ...         ...         ...         ...         ...         ...           ...
# 7747  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7748  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7749  -1.474280   -0.570471   -0.532418   -0.505596   -0.458389 -1.387779e-17
# 7750  -1.480634   -0.570471   -0.532418   -0.505596   -0.458389 -8.326673e-17
# 7751   1.894287    2.163899    2.336183    2.512023    2.631958  8.326673e-17
#
#            lon       DEM     Slope  Solar radiation
# 0    -0.027632  1.834978  1.314153         1.849430
# 1     0.497283  0.055979 -0.385336         1.400702
# 2     0.836548 -0.364575 -0.949164         1.380650
# 3     0.368125  0.084879  1.235263         1.357783
# 4     1.871193 -0.290442 -0.401730         1.366748
# ...        ...       ...       ...              ...
# 7747 -1.257759 -1.578128 -1.280447        -1.754608
# 7748 -1.041466 -1.400633 -1.072947        -1.760631
# 7749 -0.291792 -1.193124 -0.935044        -1.744763
# 7750 -2.020630 -1.985144 -1.477264        -1.887071
# 7751  1.871193  1.834978  1.742163         1.849430
#
# [7752 rows x 21 columns]

# %%
y
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7747    28.3
# 7748    28.6
# 7749    27.8
# 7750    17.4
# 7751    38.9
# Name: Next_Tmax, Length: 7752, dtype: float64

# %%
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,2000) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.7525743636744551
# at random state 0,the testing accuracy is :0.7634415758177573
#
#
# at random state 1,the training accuracy is :0.7524041010948932
# at random state 1,the testing accuracy is :0.7645020263789087
#
#
# at random state 2,the training accuracy is :0.755891925857986
# at random state 2,the testing accuracy is :0.7506191584693048
#
#
# at random state 3,the training accuracy is :0.755926244001085
# at random state 3,the testing accuracy is :0.750568267611808
#
#
# at random state 4,the training accuracy is :0.7515032498653773
# at random state 4,the testing accuracy is :0.7677490234021571
#
#
# at random state 5,the training accuracy is :0.7533382391533615
# at random state 5,the testing accuracy is :0.7600864436625343
#
#
# at random state 6,the training accuracy is :0.7546313845756276
# at random state 6,the testing accuracy is :0.754999763758014
#
#
# at random state 7,the training accuracy is :0.7551697168477306
# at random state 7,the testing accuracy is :0.7527667037661651
#
#
# at random state 8,the training accuracy is :0.7618268024916998
# at random state 8,the testing accuracy is :0.7258785012917397
#
#
# at random state 9,the training accuracy is :0.7537380592252525
# at random state 9,the testing accuracy is :0.7592650730414418
#
#
# at random state 10,the training accuracy is :0.7554681404931984
# at random state 10,the testing accuracy is :0.7521479533815523
#
#
# at random state 11,the training accuracy is :0.755981110932761
# at random state 11,the testing accuracy is :0.7502017580577723
#
#
# at random state 12,the training accuracy is :0.7510550859073902
# at random state 12,the testing accuracy is :0.7684795234356804
#
#
# at random state 13,the training accuracy is :0.7549141906617931
# at random state 13,the testing accuracy is :0.75456601942336
#
#
# at random state 14,the training accuracy is :0.7543897097396765
# at random state 14,the testing accuracy is :0.7567699231906551
#
#
# at random state 15,the training accuracy is :0.7599413436959467
# at random state 15,the testing accuracy is :0.7335422710948447
#
#
# at random state 16,the training accuracy is :0.7536657423358609
# at random state 16,the testing accuracy is :0.7594143794222851
#
#
# at random state 17,the training accuracy is :0.7555248003107291
# at random state 17,the testing accuracy is :0.7518654964667758
#
#
# at random state 18,the training accuracy is :0.7611470565994386
# at random state 18,the testing accuracy is :0.7273215758406906
#
#
# at random state 19,the training accuracy is :0.7581219259282699
# at random state 19,the testing accuracy is :0.7402130296627509
#
#
# at random state 20,the training accuracy is :0.7532650703290373
# at random state 20,the testing accuracy is :0.760668919642447
#
#
# at random state 21,the training accuracy is :0.7555608812467645
# at random state 21,the testing accuracy is :0.7517796846724308
#
#
# at random state 22,the training accuracy is :0.7594066146228907
# at random state 22,the testing accuracy is :0.7361210987285864
#
#
# at random state 23,the training accuracy is :0.7556133026027518
# at random state 23,the testing accuracy is :0.7519787827683663
#
#
# at random state 24,the training accuracy is :0.7502224418937649
# at random state 24,the testing accuracy is :0.772497848248258
#
#
# at random state 25,the training accuracy is :0.7551897032847262
# at random state 25,the testing accuracy is :0.7533645454850432
#
#
# at random state 26,the training accuracy is :0.7553179320950167
# at random state 26,the testing accuracy is :0.7529679944258486
#
#
# at random state 27,the training accuracy is :0.7549254951778852
# at random state 27,the testing accuracy is :0.7542196357729333
#
#
# at random state 28,the training accuracy is :0.7505132304015653
# at random state 28,the testing accuracy is :0.7704053658542426
#
#
# at random state 29,the training accuracy is :0.7581892362426929
# at random state 29,the testing accuracy is :0.7408246220436906
#
#
# at random state 30,the training accuracy is :0.7539475009582962
# at random state 30,the testing accuracy is :0.7581839979298218
#
#
# at random state 31,the training accuracy is :0.7571125714451301
# at random state 31,the testing accuracy is :0.7449462767430055
#
#
# at random state 32,the training accuracy is :0.7568991801101067
# at random state 32,the testing accuracy is :0.7456746397017824
#
#
# at random state 33,the training accuracy is :0.7578290314235936
# at random state 33,the testing accuracy is :0.7420030517918557
#
#
# at random state 34,the training accuracy is :0.7530391684503942
# at random state 34,the testing accuracy is :0.7613034917151766
#
#
# at random state 35,the training accuracy is :0.7587371891832531
# at random state 35,the testing accuracy is :0.7382808638245918
#
#
# at random state 36,the training accuracy is :0.7542723826601562
# at random state 36,the testing accuracy is :0.7571066560440928
#
#
# at random state 37,the training accuracy is :0.7555770956220503
# at random state 37,the testing accuracy is :0.7518530801499312
#
#
# at random state 38,the training accuracy is :0.7515056161151923
# at random state 38,the testing accuracy is :0.7679422102464938
#
#
# at random state 39,the training accuracy is :0.7547513057009949
# at random state 39,the testing accuracy is :0.7552433739655998
#
#
# at random state 40,the training accuracy is :0.7540812767293745
# at random state 40,the testing accuracy is :0.7575230075688784
#
#
# at random state 41,the training accuracy is :0.7567014802170362
# at random state 41,the testing accuracy is :0.7473702867460397
#
#
# at random state 42,the training accuracy is :0.7547458177325692
# at random state 42,the testing accuracy is :0.754695404013684
#
#
# at random state 43,the training accuracy is :0.7507499535580082
# at random state 43,the testing accuracy is :0.7711748972629259
#
#
# at random state 44,the training accuracy is :0.7564851898970069
# at random state 44,the testing accuracy is :0.7474581513644276
#
#
# at random state 45,the training accuracy is :0.7546362274244549
# at random state 45,the testing accuracy is :0.7546451112842134
#
#
# at random state 46,the training accuracy is :0.7540101710995176
# at random state 46,the testing accuracy is :0.7579293864877427
#
#
# at random state 47,the training accuracy is :0.7588833372475098
# at random state 47,the testing accuracy is :0.7368755890161209
#
#
# at random state 48,the training accuracy is :0.7545560282741169
# at random state 48,the testing accuracy is :0.7558343415918027
#
#
# at random state 49,the training accuracy is :0.7549448848055497
# at random state 49,the testing accuracy is :0.7544579108054338
#
#
# at random state 50,the training accuracy is :0.763997930575132
# at random state 50,the testing accuracy is :0.7171249204428777
#
#
# at random state 51,the training accuracy is :0.7529380812754236
# at random state 51,the testing accuracy is :0.7620686149138886
#
#
# at random state 52,the training accuracy is :0.7545805844869535
# at random state 52,the testing accuracy is :0.7557610644224573
#
#
# at random state 53,the training accuracy is :0.7547346545277697
# at random state 53,the testing accuracy is :0.7548123768210644
#
#
# at random state 54,the training accuracy is :0.7564675145442123
# at random state 54,the testing accuracy is :0.7480703505966328
#
#
# at random state 55,the training accuracy is :0.7554183864793628
# at random state 55,the testing accuracy is :0.7525422390992371
#
#
# at random state 56,the training accuracy is :0.7501823002526331
# at random state 56,the testing accuracy is :0.7709157891112899
#
#
# at random state 57,the training accuracy is :0.7590808232582449
# at random state 57,the testing accuracy is :0.7376916812288405
#
#
# at random state 58,the training accuracy is :0.7549150944027908
# at random state 58,the testing accuracy is :0.7538693002058097
#
#
# at random state 59,the training accuracy is :0.7495958147993236
# at random state 59,the testing accuracy is :0.7744332365549194
#
#
# at random state 60,the training accuracy is :0.753368968622563
# at random state 60,the testing accuracy is :0.760147651969921
#
#
# at random state 61,the training accuracy is :0.7511453084076143
# at random state 61,the testing accuracy is :0.7695812325797486
#
#
# at random state 62,the training accuracy is :0.7526310164704793
# at random state 62,the testing accuracy is :0.7634063509165991
#
#
# at random state 63,the training accuracy is :0.7530504215017566
# at random state 63,the testing accuracy is :0.7609170810921415
#
#
# at random state 64,the training accuracy is :0.7573309611624094
# at random state 64,the testing accuracy is :0.7443932513800182
#
#
# at random state 65,the training accuracy is :0.758049851304559
# at random state 65,the testing accuracy is :0.7419630483245128
#
#
# at random state 66,the training accuracy is :0.7583116180678185
# at random state 66,the testing accuracy is :0.7408645925959985
#
#
# at random state 67,the training accuracy is :0.7534696577282544
# at random state 67,the testing accuracy is :0.7605282175848855
#
#
# at random state 68,the training accuracy is :0.753151985127403
# at random state 68,the testing accuracy is :0.761242594631487
#
#
# at random state 69,the training accuracy is :0.753999092651739
# at random state 69,the testing accuracy is :0.7583750790777665
#
#
# at random state 70,the training accuracy is :0.7569868610595051
# at random state 70,the testing accuracy is :0.7460452290539038
#
#
# at random state 71,the training accuracy is :0.7530874221342646
# at random state 71,the testing accuracy is :0.7608105089547694
#
#
# at random state 72,the training accuracy is :0.7546117798704959
# at random state 72,the testing accuracy is :0.7554753091074565
#
#
# at random state 73,the training accuracy is :0.7547756580008521
# at random state 73,the testing accuracy is :0.7548733123343422
#
#
# at random state 74,the training accuracy is :0.754296560409311
# at random state 74,the testing accuracy is :0.756775305519327
#
#
# at random state 75,the training accuracy is :0.7591033354956236
# at random state 75,the testing accuracy is :0.737775895047696
#
#
# at random state 76,the training accuracy is :0.7556543066897494
# at random state 76,the testing accuracy is :0.7518792316028706
#
#
# at random state 77,the training accuracy is :0.7558082574636577
# at random state 77,the testing accuracy is :0.7509636872842069
#
#
# at random state 78,the training accuracy is :0.7538316942106992
# at random state 78,the testing accuracy is :0.7589450869013525
#
#
# at random state 79,the training accuracy is :0.7510148736097036
# at random state 79,the testing accuracy is :0.7707086938049857
#
#
# at random state 80,the training accuracy is :0.7560066816237814
# at random state 80,the testing accuracy is :0.7500891323901131
#
#
# at random state 81,the training accuracy is :0.756911691227024
# at random state 81,the testing accuracy is :0.7457661385231633
#
#
# at random state 82,the training accuracy is :0.7558858730270568
# at random state 82,the testing accuracy is :0.7507285833320755
#
#
# at random state 83,the training accuracy is :0.7599682773004258
# at random state 83,the testing accuracy is :0.7344741602230735
#
#
# at random state 84,the training accuracy is :0.7545188817149934
# at random state 84,the testing accuracy is :0.7556963203522278
#
#
# at random state 85,the training accuracy is :0.7593488964635865
# at random state 85,the testing accuracy is :0.7369090483128373
#
#
# at random state 86,the training accuracy is :0.7529524166248458
# at random state 86,the testing accuracy is :0.7622207479921088
#
#
# at random state 87,the training accuracy is :0.7582227833816126
# at random state 87,the testing accuracy is :0.7411952752057569
#
#
# at random state 88,the training accuracy is :0.7511119308517866
# at random state 88,the testing accuracy is :0.7687458371373677
#
#
# at random state 89,the training accuracy is :0.7521610165783897
# at random state 89,the testing accuracy is :0.7653968890121007
#
#
# at random state 90,the training accuracy is :0.7507427541512288
# at random state 90,the testing accuracy is :0.7700306581538847
#
#
# at random state 91,the training accuracy is :0.7581663931882807
# at random state 91,the testing accuracy is :0.7396801780443436
#
#
# at random state 92,the training accuracy is :0.7564357777498358
# at random state 92,the testing accuracy is :0.7481461104053297
#
#
# at random state 93,the training accuracy is :0.7551228243752706
# at random state 93,the testing accuracy is :0.7536296628472425
#
#
# at random state 94,the training accuracy is :0.7510409400572164
# at random state 94,the testing accuracy is :0.7687025133587905
#
#
# at random state 95,the training accuracy is :0.7565204845616511
# at random state 95,the testing accuracy is :0.7477798841949319
#
#
# at random state 96,the training accuracy is :0.7564385109548242
# at random state 96,the testing accuracy is :0.7480153093486273
#
#
# at random state 97,the training accuracy is :0.756267029994761
# at random state 97,the testing accuracy is :0.7484848496432261
#
#
# at random state 98,the training accuracy is :0.7581901586358356
# at random state 98,the testing accuracy is :0.741545964344723
#
#
# at random state 99,the training accuracy is :0.7551171824168735
# at random state 99,the testing accuracy is :0.7528606167980677
#
#
# at random state 100,the training accuracy is :0.7571194254686311
# at random state 100,the testing accuracy is :0.7452716181376311
#
#
# at random state 101,the training accuracy is :0.7521930804494165
# at random state 101,the testing accuracy is :0.7645418584070828
#
#
# at random state 102,the training accuracy is :0.7508321981816974
# at random state 102,the testing accuracy is :0.7702205965336604
#
#
# at random state 103,the training accuracy is :0.7576012023381656
# at random state 103,the testing accuracy is :0.743047883745133
#
#
# at random state 104,the training accuracy is :0.7533255837175303
# at random state 104,the testing accuracy is :0.7602268622627515
#
#
# at random state 105,the training accuracy is :0.7504195733305554
# at random state 105,the testing accuracy is :0.7715860079243959
#
#
# at random state 106,the training accuracy is :0.7531258946781558
# at random state 106,the testing accuracy is :0.761672463468923
#
#
# at random state 107,the training accuracy is :0.7600179629288589
# at random state 107,the testing accuracy is :0.731914251898856
#
#
# at random state 108,the training accuracy is :0.7519241144391274
# at random state 108,the testing accuracy is :0.7658643867616644
#
#
# at random state 109,the training accuracy is :0.7542395187439205
# at random state 109,the testing accuracy is :0.7570470808353359
#
#
# at random state 110,the training accuracy is :0.7571888446947785
# at random state 110,the testing accuracy is :0.7451049042177071
#
#
# at random state 111,the training accuracy is :0.7539376635163971
# at random state 111,the testing accuracy is :0.7579996398145911
#
#
# at random state 112,the training accuracy is :0.7565481506698983
# at random state 112,the testing accuracy is :0.7481334820294323
#
#
# at random state 113,the training accuracy is :0.7561656824819761
# at random state 113,the testing accuracy is :0.7485440355672885
#
#
# at random state 114,the training accuracy is :0.7536262760936444
# at random state 114,the testing accuracy is :0.7599117577095716
#
#
# at random state 115,the training accuracy is :0.7544695371399922
# at random state 115,the testing accuracy is :0.7559008005583022
#
#
# at random state 116,the training accuracy is :0.7508585759667181
# at random state 116,the testing accuracy is :0.7693844238401446
#
#
# at random state 117,the training accuracy is :0.756093319755038
# at random state 117,the testing accuracy is :0.7496267841062294
#
#
# at random state 118,the training accuracy is :0.752240877871644
# at random state 118,the testing accuracy is :0.763198417612551
#
#
# at random state 119,the training accuracy is :0.7546318258156705
# at random state 119,the testing accuracy is :0.7553950063993836
#
#
# at random state 120,the training accuracy is :0.7513476617085779
# at random state 120,the testing accuracy is :0.7689671186995184
#
#
# at random state 121,the training accuracy is :0.7543484236764935
# at random state 121,the testing accuracy is :0.756303163719575
#
#
# at random state 122,the training accuracy is :0.7565566621154018
# at random state 122,the testing accuracy is :0.7463012378353318
#
#
# at random state 123,the training accuracy is :0.7540582199992758
# at random state 123,the testing accuracy is :0.7575401665277222
#
#
# at random state 124,the training accuracy is :0.7540008170756642
# at random state 124,the testing accuracy is :0.7579096337551832
#
#
# at random state 125,the training accuracy is :0.75469750574977
# at random state 125,the testing accuracy is :0.7553972132215518
#
#
# at random state 126,the training accuracy is :0.7562719643863693
# at random state 126,the testing accuracy is :0.7480784947799577
#
#
# at random state 127,the training accuracy is :0.7535471206949361
# at random state 127,the testing accuracy is :0.7604963409467367
#
#
# at random state 128,the training accuracy is :0.7590163436427607
# at random state 128,the testing accuracy is :0.7378643864606493
#
#
# at random state 129,the training accuracy is :0.7543226454911645
# at random state 129,the testing accuracy is :0.7563728921326003
#
#
# at random state 130,the training accuracy is :0.7584579131214417
# at random state 130,the testing accuracy is :0.7395042946491549
#
#
# at random state 131,the training accuracy is :0.7541084617995931
# at random state 131,the testing accuracy is :0.7570925152091084
#
#
# at random state 132,the training accuracy is :0.7555845902012207
# at random state 132,the testing accuracy is :0.751408237855316
#
#
# at random state 133,the training accuracy is :0.750738298958682
# at random state 133,the testing accuracy is :0.770367279466273
#
#
# at random state 134,the training accuracy is :0.7580139954956148
# at random state 134,the testing accuracy is :0.7419070453281174
#
#
# at random state 135,the training accuracy is :0.7612052752626486
# at random state 135,the testing accuracy is :0.7266687912507565
#
#
# at random state 136,the training accuracy is :0.7584727602089398
# at random state 136,the testing accuracy is :0.7398897814940009
#
#
# at random state 137,the training accuracy is :0.7580290449837421
# at random state 137,the testing accuracy is :0.741320038131875
#
#
# at random state 138,the training accuracy is :0.7528285389492823
# at random state 138,the testing accuracy is :0.7628870318306658
#
#
# at random state 139,the training accuracy is :0.7575639545602277
# at random state 139,the testing accuracy is :0.7435316256673958
#
#
# at random state 140,the training accuracy is :0.7588951239749042
# at random state 140,the testing accuracy is :0.7380222553468073
#
#
# at random state 141,the training accuracy is :0.7539748683739708
# at random state 141,the testing accuracy is :0.7581907015542851
#
#
# at random state 142,the training accuracy is :0.7541406837262282
# at random state 142,the testing accuracy is :0.7569238260028716
#
#
# at random state 143,the training accuracy is :0.7531622273974709
# at random state 143,the testing accuracy is :0.7608012978549362
#
#
# at random state 144,the training accuracy is :0.7560841649091179
# at random state 144,the testing accuracy is :0.749201604108506
#
#
# at random state 145,the training accuracy is :0.7537691690239254
# at random state 145,the testing accuracy is :0.7588474135613666
#
#
# at random state 146,the training accuracy is :0.7525356656159793
# at random state 146,the testing accuracy is :0.7638281232170748
#
#
# at random state 147,the training accuracy is :0.7556658940134874
# at random state 147,the testing accuracy is :0.7518616663811697
#
#
# at random state 148,the training accuracy is :0.7592574227856138
# at random state 148,the testing accuracy is :0.7363382513827887
#
#
# at random state 149,the training accuracy is :0.7540950992990118
# at random state 149,the testing accuracy is :0.7575337923414132
#
#
# at random state 150,the training accuracy is :0.7593212751929737
# at random state 150,the testing accuracy is :0.7362793784634094
#
#
# at random state 151,the training accuracy is :0.7564250349985387
# at random state 151,the testing accuracy is :0.7483110811818954
#
#
# at random state 152,the training accuracy is :0.7512582331059723
# at random state 152,the testing accuracy is :0.7687793598592256
#
#
# at random state 153,the training accuracy is :0.7566195205704168
# at random state 153,the testing accuracy is :0.7463712441266175
#
#
# at random state 154,the training accuracy is :0.7539365871522787
# at random state 154,the testing accuracy is :0.7586512033701501
#
#
# at random state 155,the training accuracy is :0.7543769360346415
# at random state 155,the testing accuracy is :0.7560294350321162
#
#
# at random state 156,the training accuracy is :0.7564639657525504
# at random state 156,the testing accuracy is :0.7479067640749906
#
#
# at random state 157,the training accuracy is :0.7549056071008193
# at random state 157,the testing accuracy is :0.7545942082008182
#
#
# at random state 158,the training accuracy is :0.75568782124612
# at random state 158,the testing accuracy is :0.7507117137130014
#
#
# at random state 159,the training accuracy is :0.7611981105141037
# at random state 159,the testing accuracy is :0.7269263824759423
#
#
# at random state 160,the training accuracy is :0.7474241036148737
# at random state 160,the testing accuracy is :0.781410422398211
#
#
# at random state 161,the training accuracy is :0.7562546083730626
# at random state 161,the testing accuracy is :0.7478040351564844
#
#
# at random state 162,the training accuracy is :0.7568009362344335
# at random state 162,the testing accuracy is :0.7469351247009676
#
#
# at random state 163,the training accuracy is :0.7533497467542312
# at random state 163,the testing accuracy is :0.7608999121997704
#
#
# at random state 164,the training accuracy is :0.7594635770801353
# at random state 164,the testing accuracy is :0.7352385866019671
#
#
# at random state 165,the training accuracy is :0.7567374666703839
# at random state 165,the testing accuracy is :0.7466080533752046
#
#
# at random state 166,the training accuracy is :0.7538935071745807
# at random state 166,the testing accuracy is :0.7582023341306355
#
#
# at random state 167,the training accuracy is :0.7560448300553022
# at random state 167,the testing accuracy is :0.7500462609911608
#
#
# at random state 168,the training accuracy is :0.7573039531185882
# at random state 168,the testing accuracy is :0.744652152252331
#
#
# at random state 169,the training accuracy is :0.7545483287862998
# at random state 169,the testing accuracy is :0.755703045662492
#
#
# at random state 170,the training accuracy is :0.7602984707417131
# at random state 170,the testing accuracy is :0.7324450086863104
#
#
# at random state 171,the training accuracy is :0.7546294838455396
# at random state 171,the testing accuracy is :0.7555313723859252
#
#
# at random state 172,the training accuracy is :0.7546929484825705
# at random state 172,the testing accuracy is :0.7551345207334913
#
#
# at random state 173,the training accuracy is :0.7568154646696303
# at random state 173,the testing accuracy is :0.7455593074390785
#
#
# at random state 174,the training accuracy is :0.7564109225169162
# at random state 174,the testing accuracy is :0.7480857210646621
#
#
# at random state 175,the training accuracy is :0.7601214226225289
# at random state 175,the testing accuracy is :0.7338893112878964
#
#
# at random state 176,the training accuracy is :0.7504814867316385
# at random state 176,the testing accuracy is :0.771526246182143
#
#
# at random state 177,the training accuracy is :0.7562994074574976
# at random state 177,the testing accuracy is :0.7485302504553548
#
#
# at random state 178,the training accuracy is :0.7568010769497797
# at random state 178,the testing accuracy is :0.7461887072294702
#
#
# at random state 179,the training accuracy is :0.7574857184735536
# at random state 179,the testing accuracy is :0.7434280517514283
#
#
# at random state 180,the training accuracy is :0.7582312648332215
# at random state 180,the testing accuracy is :0.7404313396966504
#
#
# at random state 181,the training accuracy is :0.7530077401531525
# at random state 181,the testing accuracy is :0.7622271376484477
#
#
# at random state 182,the training accuracy is :0.7521435963988977
# at random state 182,the testing accuracy is :0.7643799310138506
#
#
# at random state 183,the training accuracy is :0.7568514741994252
# at random state 183,the testing accuracy is :0.7464574339595699
#
#
# at random state 184,the training accuracy is :0.7523287089375259
# at random state 184,the testing accuracy is :0.7643230282262873
#
#
# at random state 185,the training accuracy is :0.757686200095323
# at random state 185,the testing accuracy is :0.7428697024586011
#
#
# at random state 186,the training accuracy is :0.7568476211937204
# at random state 186,the testing accuracy is :0.7458178804306199
#
#
# at random state 187,the training accuracy is :0.7566326092739908
# at random state 187,the testing accuracy is :0.7471290275517624
#
#
# at random state 188,the training accuracy is :0.7603711430232764
# at random state 188,the testing accuracy is :0.7309268064630396
#
#
# at random state 189,the training accuracy is :0.7572179961998204
# at random state 189,the testing accuracy is :0.7445793127956059
#
#
# at random state 190,the training accuracy is :0.7567653956001323
# at random state 190,the testing accuracy is :0.7464023583816275
#
#
# at random state 191,the training accuracy is :0.7489365463781151
# at random state 191,the testing accuracy is :0.777007243819274
#
#
# at random state 192,the training accuracy is :0.7553461059794623
# at random state 192,the testing accuracy is :0.7527178987886551
#
#
# at random state 193,the training accuracy is :0.7534496942780514
# at random state 193,the testing accuracy is :0.759857168150708
#
#
# at random state 194,the training accuracy is :0.7577255056895787
# at random state 194,the testing accuracy is :0.7414969932260767
#
#
# at random state 195,the training accuracy is :0.7585460452324089
# at random state 195,the testing accuracy is :0.740484525012238
#
#
# at random state 196,the training accuracy is :0.7522000904260978
# at random state 196,the testing accuracy is :0.7650975771681392
#
#
# at random state 197,the training accuracy is :0.7585319171851465
# at random state 197,the testing accuracy is :0.739425491680302
#
#
# at random state 198,the training accuracy is :0.7535651298957858
# at random state 198,the testing accuracy is :0.7595549032483313
#
#
# at random state 199,the training accuracy is :0.7499787068039443
# at random state 199,the testing accuracy is :0.773712869617769
#
#
# at random state 200,the training accuracy is :0.7484189324425111
# at random state 200,the testing accuracy is :0.7799182007731618
#
#
# at random state 201,the training accuracy is :0.7539227317944661
# at random state 201,the testing accuracy is :0.7578672673092733
#
#
# at random state 202,the training accuracy is :0.7553198929123246
# at random state 202,the testing accuracy is :0.7525380062243372
#
#
# at random state 203,the training accuracy is :0.75455807481696
# at random state 203,the testing accuracy is :0.755657273133708
#
#
# at random state 204,the training accuracy is :0.7567764384639617
# at random state 204,the testing accuracy is :0.7463391556347577
#
#
# at random state 205,the training accuracy is :0.750188314678388
# at random state 205,the testing accuracy is :0.7721514584243504
#
#
# at random state 206,the training accuracy is :0.7578593147829104
# at random state 206,the testing accuracy is :0.7423744366985524
#
#
# at random state 207,the training accuracy is :0.7504967667607186
# at random state 207,the testing accuracy is :0.771481826648074
#
#
# at random state 208,the training accuracy is :0.7558848943277628
# at random state 208,the testing accuracy is :0.7506184968778384
#
#
# at random state 209,the training accuracy is :0.7519970779937178
# at random state 209,the testing accuracy is :0.7662847065172731
#
#
# at random state 210,the training accuracy is :0.7569167717364531
# at random state 210,the testing accuracy is :0.7463522149327086
#
#
# at random state 211,the training accuracy is :0.7558396144222644
# at random state 211,the testing accuracy is :0.750712915429277
#
#
# at random state 212,the training accuracy is :0.7545154784523753
# at random state 212,the testing accuracy is :0.7558555533514225
#
#
# at random state 213,the training accuracy is :0.7552161823814127
# at random state 213,the testing accuracy is :0.7515943101557194
#
#
# at random state 214,the training accuracy is :0.7516897995489507
# at random state 214,the testing accuracy is :0.7665844829767887
#
#
# at random state 215,the training accuracy is :0.75371980329733
# at random state 215,the testing accuracy is :0.7588769503347945
#
#
# at random state 216,the training accuracy is :0.7525614637511007
# at random state 216,the testing accuracy is :0.7634680316000013
#
#
# at random state 217,the training accuracy is :0.7562790868236016
# at random state 217,the testing accuracy is :0.7484511855432929
#
#
# at random state 218,the training accuracy is :0.755428213852805
# at random state 218,the testing accuracy is :0.7521714726513106
#
#
# at random state 219,the training accuracy is :0.7545665181042539
# at random state 219,the testing accuracy is :0.7558056060534655
#
#
# at random state 220,the training accuracy is :0.7537260337417128
# at random state 220,the testing accuracy is :0.7594720377929818
#
#
# at random state 221,the training accuracy is :0.7600642530842947
# at random state 221,the testing accuracy is :0.7326898494892027
#
#
# at random state 222,the training accuracy is :0.7533683134742374
# at random state 222,the testing accuracy is :0.7609054348700662
#
#
# at random state 223,the training accuracy is :0.7560165771474121
# at random state 223,the testing accuracy is :0.7495244000770243
#
#
# at random state 224,the training accuracy is :0.753509855210122
# at random state 224,the testing accuracy is :0.760191891390065
#
#
# at random state 225,the training accuracy is :0.7521336663502751
# at random state 225,the testing accuracy is :0.7660707517051288
#
#
# at random state 226,the training accuracy is :0.7594561147961464
# at random state 226,the testing accuracy is :0.7365983441289625
#
#
# at random state 227,the training accuracy is :0.7586501103865635
# at random state 227,the testing accuracy is :0.7383825623547984
#
#
# at random state 228,the training accuracy is :0.7558477889158125
# at random state 228,the testing accuracy is :0.7505172280926732
#
#
# at random state 229,the training accuracy is :0.748467248965045
# at random state 229,the testing accuracy is :0.7787751175090707
#
#
# at random state 230,the training accuracy is :0.7593470398979719
# at random state 230,the testing accuracy is :0.7361284183211216
#
#
# at random state 231,the training accuracy is :0.7590816994337019
# at random state 231,the testing accuracy is :0.7363980548111015
#
#
# at random state 232,the training accuracy is :0.7557052141345084
# at random state 232,the testing accuracy is :0.7501474167717777
#
#
# at random state 233,the training accuracy is :0.7580647575873244
# at random state 233,the testing accuracy is :0.7422673495230325
#
#
# at random state 234,the training accuracy is :0.756871921391927
# at random state 234,the testing accuracy is :0.7466594221236991
#
#
# at random state 235,the training accuracy is :0.7552364396650717
# at random state 235,the testing accuracy is :0.7527151461914336
#
#
# at random state 236,the training accuracy is :0.7549203826088677
# at random state 236,the testing accuracy is :0.7540417273328425
#
#
# at random state 237,the training accuracy is :0.7513160527093329
# at random state 237,the testing accuracy is :0.768533263786863
#
#
# at random state 238,the training accuracy is :0.7563711851992271
# at random state 238,the testing accuracy is :0.7484637520243239
#
#
# at random state 239,the training accuracy is :0.7567920377051685
# at random state 239,the testing accuracy is :0.7470762641907591
#
#
# at random state 240,the training accuracy is :0.7519987875898871
# at random state 240,the testing accuracy is :0.765411260377644
#
#
# at random state 241,the training accuracy is :0.7568245734932009
# at random state 241,the testing accuracy is :0.7451728698131636
#
#
# at random state 242,the training accuracy is :0.7518603083620696
# at random state 242,the testing accuracy is :0.765411108316833
#
#
# at random state 243,the training accuracy is :0.7534690396961904
# at random state 243,the testing accuracy is :0.7602308038135693
#
#
# at random state 244,the training accuracy is :0.7556884175760936
# at random state 244,the testing accuracy is :0.7512861511617611
#
#
# at random state 245,the training accuracy is :0.7592889768525033
# at random state 245,the testing accuracy is :0.7367891324498106
#
#
# at random state 246,the training accuracy is :0.7551998785988996
# at random state 246,the testing accuracy is :0.7537382778850316
#
#
# at random state 247,the training accuracy is :0.7536836981767128
# at random state 247,the testing accuracy is :0.7597075399511454
#
#
# at random state 248,the training accuracy is :0.7495007579304329
# at random state 248,the testing accuracy is :0.7746268654707773
#
#
# at random state 249,the training accuracy is :0.7573315842758142
# at random state 249,the testing accuracy is :0.7444988611054587
#
#
# at random state 250,the training accuracy is :0.7583597172746059
# at random state 250,the testing accuracy is :0.7397335633407949
#
#
# at random state 251,the training accuracy is :0.7515889666879487
# at random state 251,the testing accuracy is :0.7676975360321509
#
#
# at random state 252,the training accuracy is :0.7556538504902361
# at random state 252,the testing accuracy is :0.7510738972225753
#
#
# at random state 253,the training accuracy is :0.7519654954309655
# at random state 253,the testing accuracy is :0.7658509042713785
#
#
# at random state 254,the training accuracy is :0.7538997409765702
# at random state 254,the testing accuracy is :0.7583079256388745
#
#
# at random state 255,the training accuracy is :0.7567031282048209
# at random state 255,the testing accuracy is :0.7469591895638634
#
#
# at random state 256,the training accuracy is :0.756342999000409
# at random state 256,the testing accuracy is :0.749167008454543
#
#
# at random state 257,the training accuracy is :0.7626347089429586
# at random state 257,the testing accuracy is :0.7216489228261522
#
#
# at random state 258,the training accuracy is :0.7564649516123905
# at random state 258,the testing accuracy is :0.7482780507493333
#
#
# at random state 259,the training accuracy is :0.7533575963633812
# at random state 259,the testing accuracy is :0.7601794134649926
#
#
# at random state 260,the training accuracy is :0.7543440620201362
# at random state 260,the testing accuracy is :0.756627019735773
#
#
# at random state 261,the training accuracy is :0.7549788075342168
# at random state 261,the testing accuracy is :0.7540898218391681
#
#
# at random state 262,the training accuracy is :0.7626500020858041
# at random state 262,the testing accuracy is :0.7219186215313173
#
#
# at random state 263,the training accuracy is :0.7542203552588993
# at random state 263,the testing accuracy is :0.757024132570272
#
#
# at random state 264,the training accuracy is :0.7549695216980495
# at random state 264,the testing accuracy is :0.7536400395304124
#
#
# at random state 265,the training accuracy is :0.7538875167775693
# at random state 265,the testing accuracy is :0.7579312794491687
#
#
# at random state 266,the training accuracy is :0.7534304815381259
# at random state 266,the testing accuracy is :0.7597643300880267
#
#
# at random state 267,the training accuracy is :0.7498348682507205
# at random state 267,the testing accuracy is :0.7723164075207966
#
#
# at random state 268,the training accuracy is :0.7542568336439966
# at random state 268,the testing accuracy is :0.7567895290406718
#
#
# at random state 269,the training accuracy is :0.7562643898802495
# at random state 269,the testing accuracy is :0.7479227005470013
#
#
# at random state 270,the training accuracy is :0.7551058788764091
# at random state 270,the testing accuracy is :0.7534242747258492
#
#
# at random state 271,the training accuracy is :0.7581884285532638
# at random state 271,the testing accuracy is :0.741210190088057
#
#
# at random state 272,the training accuracy is :0.7570528904530872
# at random state 272,the testing accuracy is :0.7453148914884539
#
#
# at random state 273,the training accuracy is :0.7585387066239905
# at random state 273,the testing accuracy is :0.7381649924596849
#
#
# at random state 274,the training accuracy is :0.7531805799857645
# at random state 274,the testing accuracy is :0.7610927770609202
#
#
# at random state 275,the training accuracy is :0.7578217192650083
# at random state 275,the testing accuracy is :0.7427347675955773
#
#
# at random state 276,the training accuracy is :0.7542132548764391
# at random state 276,the testing accuracy is :0.7571691849352981
#
#
# at random state 277,the training accuracy is :0.7572683235858118
# at random state 277,the testing accuracy is :0.7446152911157149
#
#
# at random state 278,the training accuracy is :0.7595257169751626
# at random state 278,the testing accuracy is :0.7356616535518157
#
#
# at random state 279,the training accuracy is :0.7540108018860092
# at random state 279,the testing accuracy is :0.7583287718839281
#
#
# at random state 280,the training accuracy is :0.7519705184965624
# at random state 280,the testing accuracy is :0.7659938096485397
#
#
# at random state 281,the training accuracy is :0.7541406653017237
# at random state 281,the testing accuracy is :0.7575042165566331
#
#
# at random state 282,the training accuracy is :0.7539838119299075
# at random state 282,the testing accuracy is :0.758031943464768
#
#
# at random state 283,the training accuracy is :0.7548846058265597
# at random state 283,the testing accuracy is :0.7545854418620922
#
#
# at random state 284,the training accuracy is :0.7570662699227914
# at random state 284,the testing accuracy is :0.7454924869557508
#
#
# at random state 285,the training accuracy is :0.7581618690680325
# at random state 285,the testing accuracy is :0.7408727430912647
#
#
# at random state 286,the training accuracy is :0.7513877208871604
# at random state 286,the testing accuracy is :0.7677969720306772
#
#
# at random state 287,the training accuracy is :0.7548541827532382
# at random state 287,the testing accuracy is :0.7544566721953061
#
#
# at random state 288,the training accuracy is :0.7596042663673983
# at random state 288,the testing accuracy is :0.7346474810214341
#
#
# at random state 289,the training accuracy is :0.7540327077051785
# at random state 289,the testing accuracy is :0.756677673519776
#
#
# at random state 290,the training accuracy is :0.7579028325745865
# at random state 290,the testing accuracy is :0.7424628923815314
#
#
# at random state 291,the training accuracy is :0.7575733529754565
# at random state 291,the testing accuracy is :0.7435743773997423
#
#
# at random state 292,the training accuracy is :0.7509539536870414
# at random state 292,the testing accuracy is :0.7696199401682459
#
#
# at random state 293,the training accuracy is :0.7562082568205812
# at random state 293,the testing accuracy is :0.7496755052735531
#
#
# at random state 294,the training accuracy is :0.758257491514345
# at random state 294,the testing accuracy is :0.741333484436665
#
#
# at random state 295,the training accuracy is :0.752485162916869
# at random state 295,the testing accuracy is :0.7631562507337964
#
#
# at random state 296,the training accuracy is :0.7581654593340866
# at random state 296,the testing accuracy is :0.7415359298737867
#
#
# at random state 297,the training accuracy is :0.7573372366805473
# at random state 297,the testing accuracy is :0.743763350499129
#
#
# at random state 298,the training accuracy is :0.7577629094442051
# at random state 298,the testing accuracy is :0.7415501126628734
#
#
# at random state 299,the training accuracy is :0.7567812806446886
# at random state 299,the testing accuracy is :0.7468178038815039
#
#
# at random state 300,the training accuracy is :0.7576892243208597
# at random state 300,the testing accuracy is :0.7414767708631299
#
#
# at random state 301,the training accuracy is :0.7493704322264376
# at random state 301,the testing accuracy is :0.7763723759529719
#
#
# at random state 302,the training accuracy is :0.7568331073693
# at random state 302,the testing accuracy is :0.7462556136902048
#
#
# at random state 303,the training accuracy is :0.7530788923284455
# at random state 303,the testing accuracy is :0.7616749930092622
#
#
# at random state 304,the training accuracy is :0.7517181886373259
# at random state 304,the testing accuracy is :0.7655988245176596
#
#
# at random state 305,the training accuracy is :0.7586002566762066
# at random state 305,the testing accuracy is :0.737987512520607
#
#
# at random state 306,the training accuracy is :0.759674090829769
# at random state 306,the testing accuracy is :0.7346763702417948
#
#
# at random state 307,the training accuracy is :0.7576018308596667
# at random state 307,the testing accuracy is :0.7438262404741126
#
#
# at random state 308,the training accuracy is :0.7542167471756831
# at random state 308,the testing accuracy is :0.7566401522828203
#
#
# at random state 309,the training accuracy is :0.7540938372501295
# at random state 309,the testing accuracy is :0.7576777509527352
#
#
# at random state 310,the training accuracy is :0.7528683063271144
# at random state 310,the testing accuracy is :0.7626215316540966
#
#
# at random state 311,the training accuracy is :0.7585820444546377
# at random state 311,the testing accuracy is :0.739498665425316
#
#
# at random state 312,the training accuracy is :0.753834607916881
# at random state 312,the testing accuracy is :0.7586572510814948
#
#
# at random state 313,the training accuracy is :0.7527006650962516
# at random state 313,the testing accuracy is :0.7631306863407654
#
#
# at random state 314,the training accuracy is :0.7596992155646305
# at random state 314,the testing accuracy is :0.7343334527963892
#
#
# at random state 315,the training accuracy is :0.7522600571897913
# at random state 315,the testing accuracy is :0.7644388478469439
#
#
# at random state 316,the training accuracy is :0.7630378294488604
# at random state 316,the testing accuracy is :0.721374799484419
#
#
# at random state 317,the training accuracy is :0.7588889104963704
# at random state 317,the testing accuracy is :0.7375592359536873
#
#
# at random state 318,the training accuracy is :0.7507742790576635
# at random state 318,the testing accuracy is :0.7706574014991496
#
#
# at random state 319,the training accuracy is :0.755157289135129
# at random state 319,the testing accuracy is :0.7530337166423925
#
#
# at random state 320,the training accuracy is :0.7565559292491145
# at random state 320,the testing accuracy is :0.7476086460812807
#
#
# at random state 321,the training accuracy is :0.7478385638426854
# at random state 321,the testing accuracy is :0.7799449528771853
#
#
# at random state 322,the training accuracy is :0.7551065807200894
# at random state 322,the testing accuracy is :0.7530226484890535
#
#
# at random state 323,the training accuracy is :0.7528542190781735
# at random state 323,the testing accuracy is :0.7627211461117817
#
#
# at random state 324,the training accuracy is :0.7553220490723588
# at random state 324,the testing accuracy is :0.7524893612885432
#
#
# at random state 325,the training accuracy is :0.7571673903012515
# at random state 325,the testing accuracy is :0.7448015134964456
#
#
# at random state 326,the training accuracy is :0.756699221681576
# at random state 326,the testing accuracy is :0.7469060048337011
#
#
# at random state 327,the training accuracy is :0.7547651400137629
# at random state 327,the testing accuracy is :0.7544283060591985
#
#
# at random state 328,the training accuracy is :0.7535398938196533
# at random state 328,the testing accuracy is :0.7598985884845215
#
#
# at random state 329,the training accuracy is :0.7555352844751531
# at random state 329,the testing accuracy is :0.7516200513315958
#
#
# at random state 330,the training accuracy is :0.7614364415754851
# at random state 330,the testing accuracy is :0.7288497411211923
#
#
# at random state 331,the training accuracy is :0.7592400844674906
# at random state 331,the testing accuracy is :0.7362021770360899
#
#
# at random state 332,the training accuracy is :0.7529262857690683
# at random state 332,the testing accuracy is :0.7624467632279001
#
#
# at random state 333,the training accuracy is :0.7553624281311873
# at random state 333,the testing accuracy is :0.7524476313693894
#
#
# at random state 334,the training accuracy is :0.7588657546621735
# at random state 334,the testing accuracy is :0.7393778307596415
#
#
# at random state 335,the training accuracy is :0.7484196921023192
# at random state 335,the testing accuracy is :0.7796714580948801
#
#
# at random state 336,the training accuracy is :0.7572218954955137
# at random state 336,the testing accuracy is :0.7436968830414576
#
#
# at random state 337,the training accuracy is :0.7555695136461285
# at random state 337,the testing accuracy is :0.7512630760690437
#
#
# at random state 338,the training accuracy is :0.7570378918957318
# at random state 338,the testing accuracy is :0.7457666024980858
#
#
# at random state 339,the training accuracy is :0.7537916675504366
# at random state 339,the testing accuracy is :0.7586973515340383
#
#
# at random state 340,the training accuracy is :0.7569463610694932
# at random state 340,the testing accuracy is :0.746308209144594
#
#
# at random state 341,the training accuracy is :0.7573155080937733
# at random state 341,the testing accuracy is :0.7445069171017529
#
#
# at random state 342,the training accuracy is :0.7552660968550559
# at random state 342,the testing accuracy is :0.752901873481614
#
#
# at random state 343,the training accuracy is :0.7546072431157561
# at random state 343,the testing accuracy is :0.7556188046623457
#
#
# at random state 344,the training accuracy is :0.7549125778872573
# at random state 344,the testing accuracy is :0.7544194299880307
#
#
# at random state 345,the training accuracy is :0.7548365449676642
# at random state 345,the testing accuracy is :0.7542074809784307
#
#
# at random state 346,the training accuracy is :0.756092107175365
# at random state 346,the testing accuracy is :0.7494032771731423
#
#
# at random state 347,the training accuracy is :0.7545910578116151
# at random state 347,the testing accuracy is :0.7554639608287064
#
#
# at random state 348,the training accuracy is :0.7503889975956446
# at random state 348,the testing accuracy is :0.7721115347701557
#
#
# at random state 349,the training accuracy is :0.7518308236686253
# at random state 349,the testing accuracy is :0.7658091375135954
#
#
# at random state 350,the training accuracy is :0.748800989703954
# at random state 350,the testing accuracy is :0.7777502326049208
#
#
# at random state 351,the training accuracy is :0.7548783534313144
# at random state 351,the testing accuracy is :0.7541504245688816
#
#
# at random state 352,the training accuracy is :0.7569369943479153
# at random state 352,the testing accuracy is :0.7460054680509056
#
#
# at random state 353,the training accuracy is :0.7570626858866856
# at random state 353,the testing accuracy is :0.7450460000752824
#
#
# at random state 354,the training accuracy is :0.7575862042944013
# at random state 354,the testing accuracy is :0.7434804318758179
#
#
# at random state 355,the training accuracy is :0.7556692664294639
# at random state 355,the testing accuracy is :0.7510883663287311
#
#
# at random state 356,the training accuracy is :0.7607637603372865
# at random state 356,the testing accuracy is :0.7284137279680027
#
#
# at random state 357,the training accuracy is :0.7531333004631818
# at random state 357,the testing accuracy is :0.7615692746214915
#
#
# at random state 358,the training accuracy is :0.7554166060960701
# at random state 358,the testing accuracy is :0.7521668966347024
#
#
# at random state 359,the training accuracy is :0.7550959720410785
# at random state 359,the testing accuracy is :0.7538093453443575
#
#
# at random state 360,the training accuracy is :0.7556774160190554
# at random state 360,the testing accuracy is :0.7507558796737342
#
#
# at random state 361,the training accuracy is :0.756126056113645
# at random state 361,the testing accuracy is :0.7496084168336201
#
#
# at random state 362,the training accuracy is :0.7554612658190479
# at random state 362,the testing accuracy is :0.752101378291768
#
#
# at random state 363,the training accuracy is :0.7530896990450162
# at random state 363,the testing accuracy is :0.7620612644418732
#
#
# at random state 364,the training accuracy is :0.7583366803045459
# at random state 364,the testing accuracy is :0.7401289897834349
#
#
# at random state 365,the training accuracy is :0.7564717701605452
# at random state 365,the testing accuracy is :0.7472518321194497
#
#
# at random state 366,the training accuracy is :0.7568748401137106
# at random state 366,the testing accuracy is :0.7465587299338592
#
#
# at random state 367,the training accuracy is :0.75471999966813
# at random state 367,the testing accuracy is :0.7539510101626729
#
#
# at random state 368,the training accuracy is :0.7540129999062283
# ...
#
#
# at random state 1880,the training accuracy is :0.7526439497915817
# at random state 1880,the testing accuracy is :0.7634897286170039
#
#
# at random state 1881,the training accuracy is :0.7566835263422832
# at random state 1881,the testing accuracy is :0.7472404082934645
#
#
# at random state 1882,the training accuracy is :0.7563283973991326
# at random state 1882,the testing accuracy is :0.7483042952585677
#
#
# at random state 1883,the training accuracy is :0.7537177318054981
# at random state 1883,the testing accuracy is :0.7593426807406438
#
#
# at random state 1884,the training accuracy is :0.7494581158338807
# at random state 1884,the testing accuracy is :0.7741407438551118
#
#
# at random state 1885,the training accuracy is :0.7523856199717865
# at random state 1885,the testing accuracy is :0.7645583177070757
#
#
# at random state 1886,the training accuracy is :0.754266957206077
# at random state 1886,the testing accuracy is :0.7568970643491654
#
#
# at random state 1887,the training accuracy is :0.75609336221032
# at random state 1887,the testing accuracy is :0.7496669418466486
#
#
# at random state 1888,the training accuracy is :0.7597472379321876
# at random state 1888,the testing accuracy is :0.735874013600295
#
#
# at random state 1889,the training accuracy is :0.7522151143283851
# at random state 1889,the testing accuracy is :0.7641404969474083
#
#
# at random state 1890,the training accuracy is :0.7525502343257737
# at random state 1890,the testing accuracy is :0.7635843036126361
#
#
# at random state 1891,the training accuracy is :0.7521199312946927
# at random state 1891,the testing accuracy is :0.7651630044926884
#
#
# at random state 1892,the training accuracy is :0.755591610121951
# at random state 1892,the testing accuracy is :0.7515897791762023
#
#
# at random state 1893,the training accuracy is :0.7547862305510319
# at random state 1893,the testing accuracy is :0.7545373149948069
#
#
# at random state 1894,the training accuracy is :0.7555867007474837
# at random state 1894,the testing accuracy is :0.7513666371570609
#
#
# at random state 1895,the training accuracy is :0.7494983068334298
# at random state 1895,the testing accuracy is :0.7755224132390091
#
#
# at random state 1896,the training accuracy is :0.754058768920543
# at random state 1896,the testing accuracy is :0.7578362565686572
#
#
# at random state 1897,the training accuracy is :0.7588176369923652
# at random state 1897,the testing accuracy is :0.7388138118294365
#
#
# at random state 1898,the training accuracy is :0.7564467990431115
# at random state 1898,the testing accuracy is :0.7484688333216631
#
#
# at random state 1899,the training accuracy is :0.7614589483525318
# at random state 1899,the testing accuracy is :0.7280686642288966
#
#
# at random state 1900,the training accuracy is :0.756594551507356
# at random state 1900,the testing accuracy is :0.7469523591401892
#
#
# at random state 1901,the training accuracy is :0.7579050850989016
# at random state 1901,the testing accuracy is :0.7418081532225453
#
#
# at random state 1902,the training accuracy is :0.7566487648393757
# at random state 1902,the testing accuracy is :0.7470074014942556
#
#
# at random state 1903,the training accuracy is :0.7535975452234955
# at random state 1903,the testing accuracy is :0.759440148322233
#
#
# at random state 1904,the training accuracy is :0.7582884653698397
# at random state 1904,the testing accuracy is :0.7409217940205621
#
#
# at random state 1905,the training accuracy is :0.7515714575386375
# at random state 1905,the testing accuracy is :0.7672246719265892
#
#
# at random state 1906,the training accuracy is :0.7563801177816482
# at random state 1906,the testing accuracy is :0.748773475548133
#
#
# at random state 1907,the training accuracy is :0.7529288566705447
# at random state 1907,the testing accuracy is :0.7605475433597584
#
#
# at random state 1908,the training accuracy is :0.7560293002243627
# at random state 1908,the testing accuracy is :0.7504890010374881
#
#
# at random state 1909,the training accuracy is :0.7566074940846872
# at random state 1909,the testing accuracy is :0.7464701966132543
#
#
# at random state 1910,the training accuracy is :0.7586320849304189
# at random state 1910,the testing accuracy is :0.7380245501207501
#
#
# at random state 1911,the training accuracy is :0.7592433958038318
# at random state 1911,the testing accuracy is :0.7354772153353752
#
#
# at random state 1912,the training accuracy is :0.7543777514005032
# at random state 1912,the testing accuracy is :0.7564062512954994
#
#
# at random state 1913,the training accuracy is :0.7540024826581924
# at random state 1913,the testing accuracy is :0.7574890381437959
#
#
# at random state 1914,the training accuracy is :0.7529571272945423
# at random state 1914,the testing accuracy is :0.7623427290826795
#
#
# at random state 1915,the training accuracy is :0.7529022995119039
# at random state 1915,the testing accuracy is :0.7619159110180771
#
#
# at random state 1916,the training accuracy is :0.7473960038677122
# at random state 1916,the testing accuracy is :0.7835114991234219
#
#
# at random state 1917,the training accuracy is :0.7604708266089011
# at random state 1917,the testing accuracy is :0.7300725149006648
#
#
# at random state 1918,the training accuracy is :0.7589677735224784
# at random state 1918,the testing accuracy is :0.7369767080895842
#
#
# at random state 1919,the training accuracy is :0.7542313663238746
# at random state 1919,the testing accuracy is :0.7557497550059341
#
#
# at random state 1920,the training accuracy is :0.7565562139056048
# at random state 1920,the testing accuracy is :0.7475434705789146
#
#
# at random state 1921,the training accuracy is :0.7556358270795351
# at random state 1921,the testing accuracy is :0.7503467291000203
#
#
# at random state 1922,the training accuracy is :0.7525427464477741
# at random state 1922,the testing accuracy is :0.7637288891246454
#
#
# at random state 1923,the training accuracy is :0.7492101623152565
# at random state 1923,the testing accuracy is :0.7758427505479978
#
#
# at random state 1924,the training accuracy is :0.7584283357987387
# at random state 1924,the testing accuracy is :0.7403559449041697
#
#
# at random state 1925,the training accuracy is :0.7543705553328253
# at random state 1925,the testing accuracy is :0.75582017406043
#
#
# at random state 1926,the training accuracy is :0.7581036752494889
# at random state 1926,the testing accuracy is :0.7412817659329703
#
#
# at random state 1927,the training accuracy is :0.7562634219508786
# at random state 1927,the testing accuracy is :0.7493384413658077
#
#
# at random state 1928,the training accuracy is :0.7556045808949006
# at random state 1928,the testing accuracy is :0.7513352284771735
#
#
# at random state 1929,the training accuracy is :0.7569655969737524
# at random state 1929,the testing accuracy is :0.7462487618550235
#
#
# at random state 1930,the training accuracy is :0.7544510563187158
# at random state 1930,the testing accuracy is :0.7564693089920572
#
#
# at random state 1931,the training accuracy is :0.7544600170353805
# at random state 1931,the testing accuracy is :0.7559902295369806
#
#
# at random state 1932,the training accuracy is :0.7547349759270298
# at random state 1932,the testing accuracy is :0.7554272860366027
#
#
# at random state 1933,the training accuracy is :0.7520233083905274
# at random state 1933,the testing accuracy is :0.765946670055788
#
#
# at random state 1934,the training accuracy is :0.7577858344873856
# at random state 1934,the testing accuracy is :0.7422544645289175
#
#
# at random state 1935,the training accuracy is :0.7561861905855173
# at random state 1935,the testing accuracy is :0.7492949687059176
#
#
# at random state 1936,the training accuracy is :0.7579675993197648
# at random state 1936,the testing accuracy is :0.7417279638819153
#
#
# at random state 1937,the training accuracy is :0.752314752573457
# at random state 1937,the testing accuracy is :0.7639645763967492
#
#
# at random state 1938,the training accuracy is :0.7517175254709686
# at random state 1938,the testing accuracy is :0.7668431366474318
#
#
# at random state 1939,the training accuracy is :0.7557510246466728
# at random state 1939,the testing accuracy is :0.7506324865106706
#
#
# at random state 1940,the training accuracy is :0.7539113954804622
# at random state 1940,the testing accuracy is :0.7583587746557466
#
#
# at random state 1941,the training accuracy is :0.7578203576701015
# at random state 1941,the testing accuracy is :0.7419735763403558
#
#
# at random state 1942,the training accuracy is :0.754913907852989
# at random state 1942,the testing accuracy is :0.7541702254409418
#
#
# at random state 1943,the training accuracy is :0.7577148385249867
# at random state 1943,the testing accuracy is :0.7430100275494333
#
#
# at random state 1944,the training accuracy is :0.7592074427093597
# at random state 1944,the testing accuracy is :0.7348662867442389
#
#
# at random state 1945,the training accuracy is :0.7556233916453576
# at random state 1945,the testing accuracy is :0.7515178009466698
#
#
# at random state 1946,the training accuracy is :0.7566172244612388
# at random state 1946,the testing accuracy is :0.7476649759237435
#
#
# at random state 1947,the training accuracy is :0.7538504245141325
# at random state 1947,the testing accuracy is :0.7587299640107041
#
#
# at random state 1948,the training accuracy is :0.7569862018469997
# at random state 1948,the testing accuracy is :0.7456532961475574
#
#
# at random state 1949,the training accuracy is :0.7562063448288725
# at random state 1949,the testing accuracy is :0.7495031148917877
#
#
# at random state 1950,the training accuracy is :0.7539139073328878
# at random state 1950,the testing accuracy is :0.7584723946885326
#
#
# at random state 1951,the training accuracy is :0.7608945103249343
# at random state 1951,the testing accuracy is :0.7296772036583047
#
#
# at random state 1952,the training accuracy is :0.7576448214528415
# at random state 1952,the testing accuracy is :0.7432391227954841
#
#
# at random state 1953,the training accuracy is :0.7530732358831937
# at random state 1953,the testing accuracy is :0.7620983874143992
#
#
# at random state 1954,the training accuracy is :0.75539862375303
# at random state 1954,the testing accuracy is :0.7523681975013415
#
#
# at random state 1955,the training accuracy is :0.7541062965826129
# at random state 1955,the testing accuracy is :0.756595166746995
#
#
# at random state 1956,the training accuracy is :0.7531325769823244
# at random state 1956,the testing accuracy is :0.7609159000760592
#
#
# at random state 1957,the training accuracy is :0.7550047378640713
# at random state 1957,the testing accuracy is :0.7536867053490757
#
#
# at random state 1958,the training accuracy is :0.7560384873651129
# at random state 1958,the testing accuracy is :0.7495722178884111
#
#
# at random state 1959,the training accuracy is :0.7568756744035562
# at random state 1959,the testing accuracy is :0.7456905185578707
#
#
# at random state 1960,the training accuracy is :0.7575882659927533
# at random state 1960,the testing accuracy is :0.7437740008598684
#
#
# at random state 1961,the training accuracy is :0.7518750963602114
# at random state 1961,the testing accuracy is :0.7651942007885402
#
#
# at random state 1962,the training accuracy is :0.759867499209156
# at random state 1962,the testing accuracy is :0.7342058217369318
#
#
# at random state 1963,the training accuracy is :0.7567394493264863
# at random state 1963,the testing accuracy is :0.7466774552639732
#
#
# at random state 1964,the training accuracy is :0.7568416239839961
# at random state 1964,the testing accuracy is :0.7459875010244881
#
#
# at random state 1965,the training accuracy is :0.7570465217695266
# at random state 1965,the testing accuracy is :0.7452670092718529
#
#
# at random state 1966,the training accuracy is :0.7570401624922993
# at random state 1966,the testing accuracy is :0.745233654572686
#
#
# at random state 1967,the training accuracy is :0.7555469913545599
# at random state 1967,the testing accuracy is :0.7512609312188774
#
#
# at random state 1968,the training accuracy is :0.7604766642047907
# at random state 1968,the testing accuracy is :0.7309484885001027
#
#
# at random state 1969,the training accuracy is :0.7602988415600701
# at random state 1969,the testing accuracy is :0.7320752979050817
#
#
# at random state 1970,the training accuracy is :0.7531133428909551
# at random state 1970,the testing accuracy is :0.7614147437769319
#
#
# at random state 1971,the training accuracy is :0.7569369716099664
# at random state 1971,the testing accuracy is :0.7470227507674476
#
#
# at random state 1972,the training accuracy is :0.7535141623331736
# at random state 1972,the testing accuracy is :0.7592653447942469
#
#
# at random state 1973,the training accuracy is :0.7585222202139985
# at random state 1973,the testing accuracy is :0.7394538778793133
#
#
# at random state 1974,the training accuracy is :0.7537709652220608
# at random state 1974,the testing accuracy is :0.7591759322183437
#
#
# at random state 1975,the training accuracy is :0.7570278109048654
# at random state 1975,the testing accuracy is :0.7466180029884426
#
#
# at random state 1976,the training accuracy is :0.7550877698907343
# at random state 1976,the testing accuracy is :0.7539762163654302
#
#
# at random state 1977,the training accuracy is :0.7567855726213861
# at random state 1977,the testing accuracy is :0.746706488194403
#
#
# at random state 1978,the training accuracy is :0.7567695363345704
# at random state 1978,the testing accuracy is :0.7458815307675377
#
#
# at random state 1979,the training accuracy is :0.7504218856251488
# at random state 1979,the testing accuracy is :0.7713763778831928
#
#
# at random state 1980,the training accuracy is :0.7529990375846226
# at random state 1980,the testing accuracy is :0.7605256279321837
#
#
# at random state 1981,the training accuracy is :0.7522741579717532
# at random state 1981,the testing accuracy is :0.7639862217119394
#
#
# at random state 1982,the training accuracy is :0.7573346331962323
# at random state 1982,the testing accuracy is :0.7438436696126074
#
#
# at random state 1983,the training accuracy is :0.760183246196435
# at random state 1983,the testing accuracy is :0.7323923965404968
#
#
# at random state 1984,the training accuracy is :0.7537916754071281
# at random state 1984,the testing accuracy is :0.7588984744901368
#
#
# at random state 1985,the training accuracy is :0.7575860980256498
# at random state 1985,the testing accuracy is :0.7440324257557425
#
#
# at random state 1986,the training accuracy is :0.7544381726916222
# at random state 1986,the testing accuracy is :0.7560621997686576
#
#
# at random state 1987,the training accuracy is :0.7544695372148967
# at random state 1987,the testing accuracy is :0.7560534319826413
#
#
# at random state 1988,the training accuracy is :0.7554490106375004
# at random state 1988,the testing accuracy is :0.7525214759890483
#
#
# at random state 1989,the training accuracy is :0.7543460839258385
# at random state 1989,the testing accuracy is :0.7570144068050998
#
#
# at random state 1990,the training accuracy is :0.7490004737650118
# at random state 1990,the testing accuracy is :0.777023844487124
#
#
# at random state 1991,the training accuracy is :0.7571492810712344
# at random state 1991,the testing accuracy is :0.7460016654236089
#
#
# at random state 1992,the training accuracy is :0.7560500347722906
# at random state 1992,the testing accuracy is :0.7494319468907924
#
#
# at random state 1993,the training accuracy is :0.7536409259149053
# at random state 1993,the testing accuracy is :0.7595399225897252
#
#
# at random state 1994,the training accuracy is :0.7459470844437959
# at random state 1994,the testing accuracy is :0.78799556167863
#
#
# at random state 1995,the training accuracy is :0.7517694714956943
# at random state 1995,the testing accuracy is :0.7664315853739752
#
#
# at random state 1996,the training accuracy is :0.7522533166300884
# at random state 1996,the testing accuracy is :0.7646859432509174
#
#
# at random state 1997,the training accuracy is :0.7502892044677014
# at random state 1997,the testing accuracy is :0.7725061733011999
#
#
# at random state 1998,the training accuracy is :0.7573468946301147
# at random state 1998,the testing accuracy is :0.7453411388265477
#
#
# at random state 1999,the training accuracy is :0.7592689533650105
# at random state 1999,the testing accuracy is :0.7363174987032888

# %%
As at random state 49, the testing and training accuracy is closest at 75.4%

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=49)

# %%
x_train.shape
# Out:
# (6201, 21)

# %%
y_train.shape
# Out:
# (6201,)

# %%
x_test.shape
# Out:
# (1551, 21)

# %%
y_test.shape
# Out:
# (1551,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.7544579108054338

# %%
Train_accuracy=r2_score(y_train,pred_train)        #Cross Validation
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.6638830697420709 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 3 the cv score is 0.6953525353274541 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 4 the cv score is 0.6876082370345143 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 5 the cv score is 0.6846140386903401 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 6 the cv score is 0.6823242433506325 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 7 the cv score is 0.6806614726901179 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 8 the cv score is 0.6726264510952917 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338
#
#
# At cross fold 9 the cv score is 0.6002363203957947 and accuracy score for training is -0.7710415583584138and accuracy score for testing is 0.7544579108054338

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %%
We see most of our data is in line with the Blue line, which shows the qulaity of data is very good

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.7544556927006927

# %%
cv_score=cross_val_score(ls,x,y,cv=3)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6953889719264804

# %%
We see that the model accuracy is 75.4% and the cross validation score is 69% which is close to model accuracy thus the model is not overfitted
